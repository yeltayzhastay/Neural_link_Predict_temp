# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
import keras

import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import os

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %%
df1 = pd.read_csv("bef_data_1.csv")
df2 = pd.read_csv("bef_data_2.csv")
df3 = pd.read_csv("bef_data_3.csv")
df4 = pd.read_csv("bef_data_4.csv")
df5 = pd.read_csv("bef_data_5.csv")

#df1 = df1.set_index('time')
#df1.columns = ['Temp1', 'Temp2', 'Temp3', 'Temp4', 'Temp5', 'Temp6', 'Temp7', 'Temp8', 'Temp9', 'Temp10']
#df1

# %%
def shaper(arr, n_time = 1):
    arr = arr.values.tolist()
    shape_list = []
    for i in range(0, len(arr) - n_time, 1):
        time_list = []
        for j in range(n_time):
            time_list +=arr[i + j]
        shape_list.append(time_list)
        
    columns = []
    for i in range((-n_time)+1,1,1):
        columns += ["Temp1_" + str(i), 
                    "Temp2_" + str(i), 
                    "Temp3_" + str(i), 
                    "Temp4_" + str(i), 
                    "Temp5_" + str(i), 
                    "Temp6_" + str(i), 
                    "Temp7_" + str(i), 
                    "Temp8_" + str(i), 
                    "Temp9_" + str(i), 
                    "Temp10_" + str(i),
                    #'cond1_off_' + str(i),
                    #'c1_16h_' + str(i), 
                    #'c1_16l_' + str(i), 
                    #'c1_23h_' + str(i), 
                    #'c1_23l_' + str(i), 
                    #'c1_30h_' + str(i), 
                    #'c1_30l_' + str(i), 
                    #'cond2_off_' + str(i), 
                    #'c2_16h_' + str(i), 
                    #'c2_16l_' + str(i), 
                    #'c2_23h_' + str(i), 
                    #'c2_23l_' + str(i), 
                    #'c2_30h_' + str(i), 
                    #'c2_30l_' + str(i)
                   ]
    
    td = pd.DataFrame(shape_list, columns = columns)
    return td

def union_shaper(df_list, n_time = 1):
    frames = []
    for i in range(len(df_list)):
        df = pd.DataFrame(df_list[i], columns = ["time", "Temp1","Temp2", "Temp3", "Temp4", "Temp5", "Temp6", "Temp7", "Temp8", "Temp9", "Temp10"])
        df = df.set_index('time')
        df.columns = ['Temp1', 'Temp2', 'Temp3', 'Temp4', 'Temp5', 'Temp6', 'Temp7', 'Temp8', 'Temp9', 'Temp10']
        df = shaper(df, n_time)
        
        df['Temp1+1'] = df['Temp1_0'].shift(-1)
        df['Temp2+1'] = df['Temp2_0'].shift(-1)
        df['Temp3+1'] = df['Temp3_0'].shift(-1)
        df['Temp4+1'] = df['Temp4_0'].shift(-1)
        df['Temp5+1'] = df['Temp5_0'].shift(-1)
        df['Temp6+1'] = df['Temp6_0'].shift(-1)
        df['Temp7+1'] = df['Temp7_0'].shift(-1)
        df['Temp8+1'] = df['Temp8_0'].shift(-1)
        df['Temp9+1'] = df['Temp9_0'].shift(-1)
        df['Temp10+1'] = df['Temp10_0'].shift(-1)

        df['Temp1+1'].fillna(24, inplace=True)
        df['Temp2+1'].fillna(24, inplace=True)
        df['Temp3+1'].fillna(24, inplace=True)
        df['Temp4+1'].fillna(24, inplace=True)
        df['Temp5+1'].fillna(24, inplace=True)
        df['Temp6+1'].fillna(24, inplace=True)
        df['Temp7+1'].fillna(24, inplace=True)
        df['Temp8+1'].fillna(24, inplace=True)
        df['Temp9+1'].fillna(24, inplace=True)
        df['Temp10+1'].fillna(24, inplace=True)
        frames.append(df)
    return pd.concat(frames, ignore_index=True)

# %%
N_TIME = 12
df = union_shaper([df1, df2, df3, df4, df5], N_TIME)
df
# Out:
#      Temp1_-11  Temp2_-11  Temp3_-11  Temp4_-11  Temp5_-11  Temp6_-11  \
# 0           28         27         27         27         28         27
# 1           27         27         27         27         28         27
# 2           27         27         27         27         27         26
# 3           27         26         26         27         27         26
# 4           27         26         26         26         27         26
# ..         ...        ...        ...        ...        ...        ...
# 941         24         23         23         23         24         23
# 942         24         23         23         23         24         23
# 943         24         23         23         24         24         23
# 944         23         22         23         23         23         22
# 945         24         24         24         24         25         23
#
#      Temp7_-11  Temp8_-11  Temp9_-11  Temp10_-11  ...  Temp1+1  Temp2+1  \
# 0           27         28         27          27  ...     25.0     25.0
# 1           27         28         27          27  ...     25.0     25.0
# 2           26         27         27          27  ...     25.0     25.0
# 3           26         27         27          27  ...     25.0     25.0
# 4           26         27         27          27  ...     25.0     25.0
# ..         ...        ...        ...         ...  ...      ...      ...
# 941         23         24         23          23  ...     25.0     24.0
# 942         23         24         23          23  ...     25.0     24.0
# 943         23         24         23          23  ...     25.0     24.0
# 944         22         23         23          23  ...     25.0     24.0
# 945         24         24         24          24  ...     24.0     24.0
#
#      Temp3+1  Temp4+1  Temp5+1  Temp6+1  Temp7+1  Temp8+1  Temp9+1  Temp10+1
# 0       25.0     25.0     26.0     25.0     25.0     26.0     25.0      25.0
# 1       25.0     26.0     26.0     25.0     25.0     26.0     25.0      25.0
# 2       25.0     25.0     26.0     25.0     25.0     26.0     25.0      25.0
# 3       25.0     25.0     25.0     25.0     25.0     26.0     25.0      25.0
# 4       25.0     25.0     25.0     25.0     25.0     26.0     25.0      25.0
# ..       ...      ...      ...      ...      ...      ...      ...       ...
# 941     24.0     24.0     25.0     24.0     24.0     25.0     25.0      25.0
# 942     24.0     25.0     25.0     24.0     25.0     25.0     25.0      25.0
# 943     25.0     25.0     25.0     24.0     25.0     25.0     25.0      25.0
# 944     25.0     25.0     26.0     25.0     25.0     25.0     25.0      25.0
# 945     24.0     24.0     24.0     24.0     24.0     24.0     24.0      24.0
#
# [946 rows x 130 columns]

# %% [raw]
# df['Temp1+1'] = df['Temp1_0'].shift(-1)
# df['Temp2+1'] = df['Temp2_0'].shift(-1)
# df['Temp3+1'] = df['Temp3_0'].shift(-1)
# df['Temp4+1'] = df['Temp4_0'].shift(-1)
# df['Temp5+1'] = df['Temp5_0'].shift(-1)
# df['Temp6+1'] = df['Temp6_0'].shift(-1)
# df['Temp7+1'] = df['Temp7_0'].shift(-1)
# df['Temp8+1'] = df['Temp8_0'].shift(-1)
# df['Temp9+1'] = df['Temp9_0'].shift(-1)
# df['Temp10+1'] = df['Temp10_0'].shift(-1)
#
# df['Temp1+1'].fillna(24, inplace=True)
# df['Temp2+1'].fillna(24, inplace=True)
# df['Temp3+1'].fillna(24, inplace=True)
# df['Temp4+1'].fillna(24, inplace=True)
# df['Temp5+1'].fillna(24, inplace=True)
# df['Temp6+1'].fillna(24, inplace=True)
# df['Temp7+1'].fillna(24, inplace=True)
# df['Temp8+1'].fillna(24, inplace=True)
# df['Temp9+1'].fillna(24, inplace=True)
# df['Temp10+1'].fillna(24, inplace=True)

# %%
x = df.drop(['Temp1+1', 'Temp2+1', 'Temp3+1', 'Temp4+1', 'Temp5+1', 'Temp6+1', 'Temp7+1', 'Temp8+1', 'Temp9+1', 'Temp10+1'], axis = 1)
y = df[['Temp1+1', 'Temp2+1', 'Temp3+1', 'Temp4+1', 'Temp5+1', 'Temp6+1', 'Temp7+1', 'Temp8+1', 'Temp9+1', 'Temp10+1']]

y=np.reshape(y.values, (-1,10))

scaler_x = MinMaxScaler()
print(scaler_x.fit(x))
scaler_y = MinMaxScaler()
print(scaler_y.fit(y))
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %% [markdown]
# # Variants

# %%
X_train = scaler_x.transform(x)
y_train = scaler_y.transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.1)

# %% [raw]
# X_test = scaler_x.transform(x[87:100])
# y_test = scaler_y.transform(y[87:100])

# %% [markdown]
# xscale=scaler_x.transform(x)
# yscale=scaler_y.transform(y)
#
# X_train, X_test, y_train, y_test = train_test_split(xscale, yscale, train_size = 1)

# %% [markdown]
# # Neural Link

# %%
model = Sequential()
model.add(Dense(128, input_dim=10 * N_TIME, kernel_initializer='normal', activation='relu'))
model.add(Dense(256, activation='linear'))
model.add(Dense(10, activation='linear'))
model.summary()
# Use a custom metricfunction

loss_fn = tf.keras.losses.MeanSquaredError(reduction='sum_over_batch_size')
model.compile(loss=loss_fn, optimizer='adam', metrics = ['accuracy'])

fit = model.fit(X_train, y_train, epochs=100,  verbose=1, validation_split=0.5)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 128)               15488
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 51,082
# Trainable params: 51,082
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0609 - accuracy: 0.1388 - val_loss: 0.0218 - val_accuracy: 0.0188
# Epoch 2/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 0.1176 - val_loss: 0.0092 - val_accuracy: 0.2347
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 0.1106 - val_loss: 0.0060 - val_accuracy: 0.1667
# Epoch 4/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 0.1271 - val_loss: 0.0055 - val_accuracy: 0.1878
# Epoch 5/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.1506 - val_loss: 0.0046 - val_accuracy: 0.2277
# Epoch 6/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 0.1412 - val_loss: 0.0045 - val_accuracy: 0.2441
# Epoch 7/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.1294 - val_loss: 0.0043 - val_accuracy: 0.2300
# Epoch 8/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.1741 - val_loss: 0.0074 - val_accuracy: 0.0986
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.1647 - val_loss: 0.0040 - val_accuracy: 0.2371
# Epoch 10/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 0.1765 - val_loss: 0.0039 - val_accuracy: 0.2207
# Epoch 11/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.1788 - val_loss: 0.0039 - val_accuracy: 0.1808
# Epoch 12/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 0.1412 - val_loss: 0.0041 - val_accuracy: 0.1221
# Epoch 13/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.1835 - val_loss: 0.0037 - val_accuracy: 0.2840
# Epoch 14/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 0.1506 - val_loss: 0.0037 - val_accuracy: 0.1667
# Epoch 15/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 0.1906 - val_loss: 0.0053 - val_accuracy: 0.2207
# Epoch 16/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 0.1859 - val_loss: 0.0036 - val_accuracy: 0.2441
# Epoch 17/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.1882 - val_loss: 0.0044 - val_accuracy: 0.1174
# Epoch 18/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.1576 - val_loss: 0.0036 - val_accuracy: 0.2958
# Epoch 19/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 0.2212 - val_loss: 0.0043 - val_accuracy: 0.2723
# Epoch 20/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 0.1976 - val_loss: 0.0044 - val_accuracy: 0.1174
# Epoch 21/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.1576 - val_loss: 0.0034 - val_accuracy: 0.1432
# Epoch 22/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.1741 - val_loss: 0.0035 - val_accuracy: 0.2019
# Epoch 23/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.1765 - val_loss: 0.0035 - val_accuracy: 0.2300
# Epoch 24/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.2024 - val_loss: 0.0032 - val_accuracy: 0.2465
# Epoch 25/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.2165 - val_loss: 0.0033 - val_accuracy: 0.2653
# Epoch 26/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.2047 - val_loss: 0.0033 - val_accuracy: 0.1878
# Epoch 27/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.1953 - val_loss: 0.0034 - val_accuracy: 0.2441
# Epoch 28/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.1765 - val_loss: 0.0033 - val_accuracy: 0.2535
# Epoch 29/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 0.1906 - val_loss: 0.0041 - val_accuracy: 0.1667
# Epoch 30/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.1624 - val_loss: 0.0032 - val_accuracy: 0.2512
# Epoch 31/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.2329 - val_loss: 0.0032 - val_accuracy: 0.2347
# Epoch 32/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.2094 - val_loss: 0.0047 - val_accuracy: 0.1338
# Epoch 33/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.1553 - val_loss: 0.0041 - val_accuracy: 0.2042
# Epoch 34/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 0.2000 - val_loss: 0.0035 - val_accuracy: 0.2441
# Epoch 35/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.2188 - val_loss: 0.0034 - val_accuracy: 0.2324
# Epoch 36/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.1812 - val_loss: 0.0034 - val_accuracy: 0.2230
# Epoch 37/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.2235 - val_loss: 0.0032 - val_accuracy: 0.2770
# Epoch 38/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.1953 - val_loss: 0.0032 - val_accuracy: 0.1502
# Epoch 39/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.1929 - val_loss: 0.0043 - val_accuracy: 0.2347
# Epoch 40/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.2306 - val_loss: 0.0032 - val_accuracy: 0.2136
# Epoch 41/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.2165 - val_loss: 0.0032 - val_accuracy: 0.2512
# Epoch 42/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.2306 - val_loss: 0.0037 - val_accuracy: 0.2113
# Epoch 43/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.1765 - val_loss: 0.0038 - val_accuracy: 0.2653
# Epoch 44/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.2424 - val_loss: 0.0032 - val_accuracy: 0.2136
# Epoch 45/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.1953 - val_loss: 0.0050 - val_accuracy: 0.1174
# Epoch 46/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 0.2259 - val_loss: 0.0038 - val_accuracy: 0.1432
# Epoch 47/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.2165 - val_loss: 0.0040 - val_accuracy: 0.2535
# Epoch 48/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 0.1906 - val_loss: 0.0037 - val_accuracy: 0.1901
# Epoch 49/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.2282 - val_loss: 0.0031 - val_accuracy: 0.1831
# Epoch 50/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.2071 - val_loss: 0.0032 - val_accuracy: 0.2277
# Epoch 51/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.1906 - val_loss: 0.0031 - val_accuracy: 0.1737
# Epoch 52/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.1859 - val_loss: 0.0038 - val_accuracy: 0.2512
# Epoch 53/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.1718 - val_loss: 0.0033 - val_accuracy: 0.2418
# Epoch 54/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.2000 - val_loss: 0.0046 - val_accuracy: 0.2582
# Epoch 55/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.2118 - val_loss: 0.0037 - val_accuracy: 0.2700
# Epoch 56/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.2424 - val_loss: 0.0058 - val_accuracy: 0.1761
# Epoch 57/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.1953 - val_loss: 0.0032 - val_accuracy: 0.1549
# Epoch 58/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.1788 - val_loss: 0.0036 - val_accuracy: 0.2559
# Epoch 59/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.2071 - val_loss: 0.0036 - val_accuracy: 0.2676
# Epoch 60/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.1953 - val_loss: 0.0039 - val_accuracy: 0.2465
# Epoch 61/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.2400 - val_loss: 0.0034 - val_accuracy: 0.2770
# Epoch 62/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.2165 - val_loss: 0.0032 - val_accuracy: 0.2488
# Epoch 63/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.1906 - val_loss: 0.0032 - val_accuracy: 0.2042
# Epoch 64/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.2329 - val_loss: 0.0036 - val_accuracy: 0.1667
# Epoch 65/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.1906 - val_loss: 0.0074 - val_accuracy: 0.2582
# Epoch 66/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 0.2212 - val_loss: 0.0049 - val_accuracy: 0.0399
# Epoch 67/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 0.1671 - val_loss: 0.0037 - val_accuracy: 0.1690
# Epoch 68/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.1647 - val_loss: 0.0032 - val_accuracy: 0.1854
# Epoch 69/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.2071 - val_loss: 0.0032 - val_accuracy: 0.2465
# Epoch 70/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.1882 - val_loss: 0.0032 - val_accuracy: 0.2136
# Epoch 71/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.2188 - val_loss: 0.0033 - val_accuracy: 0.1972
# Epoch 72/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.2071 - val_loss: 0.0037 - val_accuracy: 0.2230
# Epoch 73/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.2329 - val_loss: 0.0033 - val_accuracy: 0.0798
# Epoch 74/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.2306 - val_loss: 0.0031 - val_accuracy: 0.2160
# Epoch 75/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.2235 - val_loss: 0.0031 - val_accuracy: 0.2418
# Epoch 76/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.2259 - val_loss: 0.0033 - val_accuracy: 0.1150
# Epoch 77/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.2165 - val_loss: 0.0054 - val_accuracy: 0.1291
# Epoch 78/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.2165 - val_loss: 0.0034 - val_accuracy: 0.2136
# Epoch 79/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.2165 - val_loss: 0.0031 - val_accuracy: 0.2582
# Epoch 80/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.2282 - val_loss: 0.0032 - val_accuracy: 0.2019
# Epoch 81/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.2024 - val_loss: 0.0038 - val_accuracy: 0.2042
# Epoch 82/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.2071 - val_loss: 0.0034 - val_accuracy: 0.2066
# Epoch 83/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.2165 - val_loss: 0.0037 - val_accuracy: 0.1948
# Epoch 84/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.2071 - val_loss: 0.0031 - val_accuracy: 0.1901
# Epoch 85/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.2094 - val_loss: 0.0031 - val_accuracy: 0.1995
# Epoch 86/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.1953 - val_loss: 0.0040 - val_accuracy: 0.2300
# Epoch 87/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.1906 - val_loss: 0.0040 - val_accuracy: 0.2488
# Epoch 88/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.2212 - val_loss: 0.0031 - val_accuracy: 0.1573
# Epoch 89/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.2094 - val_loss: 0.0056 - val_accuracy: 0.1596
# Epoch 90/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.2165 - val_loss: 0.0036 - val_accuracy: 0.2136
# Epoch 91/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.2000 - val_loss: 0.0052 - val_accuracy: 0.2418
# Epoch 92/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.2141 - val_loss: 0.0036 - val_accuracy: 0.2019
# Epoch 93/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 0.1859 - val_loss: 0.0033 - val_accuracy: 0.2746
# Epoch 94/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.2282 - val_loss: 0.0035 - val_accuracy: 0.0775
# Epoch 95/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 0.1906 - val_loss: 0.0044 - val_accuracy: 0.2676
# Epoch 96/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.2212 - val_loss: 0.0032 - val_accuracy: 0.1150
# Epoch 97/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.2071 - val_loss: 0.0033 - val_accuracy: 0.2488
# Epoch 98/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.2188 - val_loss: 0.0031 - val_accuracy: 0.1761
# Epoch 99/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.1812 - val_loss: 0.0031 - val_accuracy: 0.1995
# Epoch 100/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.2118 - val_loss: 0.0035 - val_accuracy: 0.2653

# %%
scores = model.evaluate(X_test, y_test, verbose=1)
print("Доля верных ответов на тестовых данных, в процентах:", round(scores[1] * 100, 4))
# Out:
# 3/3 [==============================] - 0s 998us/step - loss: 0.0051 - accuracy: 0.3474
# Доля верных ответов на тестовых данных, в процентах: 34.7368

# %%
def pred_plot(x, y, p, index):
    mpl.rcParams['figure.figsize'] = (4, 3)
    mpl.rcParams['axes.grid'] = False
    
    history = np.transpose(np.reshape(x[index], (-1, 10)))
    
    length = history.shape[1]
    #np.reshape(X, (-1, 10))[-1].tolist()
    
    real = np.transpose(np.array(y[index]))
    
    pred = np.transpose(np.array(p[index]))
    
    for i in range(10):
        percent = (history[i].max() - history[i].min())
        result = (percent-abs(real[i] - pred[i]))/percent
        
        plt.plot(range(length), history[i], label='History')
        plt.plot(length, real[i], 'bo', label='Real')
        plt.plot(length, pred[i], 'rx', label='Predicted')
        plt.xlabel('Time')
        plt.ylabel('Temperature value')
        plt.legend(loc='upper left')
        plt.title('index: ' + str(index) + ', temp: ' + str(i+1) + '\npercent: ' + str(result*100))
        plt.show()

# %%
scaler_x.inverse_transform(X_test[:2])
# Out:
# array([[25., 24., 25., 25., 25., 24., 24., 25., 25., 25., 25., 24., 25.,
#         25., 25., 24., 24., 25., 25., 25., 25., 25., 25., 25., 25., 24.,
#         24., 25., 25., 25., 25., 25., 25., 25., 25., 25., 25., 25., 25.,
#         25., 25., 25., 25., 25., 25., 25., 25., 25., 25., 25., 25., 25.,
#         25., 25., 25., 25., 24., 26., 25., 25., 25., 25., 25., 25., 25.,
#         25., 25., 26., 25., 25., 26., 25., 26., 26., 26., 25., 25., 26.,
#         26., 26., 27., 26., 26., 26., 27., 26., 26., 27., 27., 27., 27.,
#         26., 27., 27., 28., 27., 27., 28., 27., 27., 28., 27., 27., 28.,
#         28., 28., 27., 28., 28., 28., 28., 27., 27., 28., 28., 28., 27.,
#         28., 28., 28.],
#        [26., 26., 26., 26., 27., 26., 26., 27., 26., 26., 26., 26., 26.,
#         26., 27., 26., 26., 27., 26., 27., 27., 26., 26., 27., 27., 26.,
#         26., 27., 27., 27., 26., 25., 26., 26., 26., 26., 26., 27., 26.,
#         26., 26., 25., 25., 25., 25., 25., 25., 26., 25., 25., 25., 24.,
#         25., 25., 25., 25., 24., 26., 25., 25., 26., 25., 25., 25., 25.,
#         25., 25., 26., 25., 25., 26., 25., 25., 25., 26., 25., 25., 26.,
#         26., 25., 27., 26., 26., 27., 27., 26., 26., 27., 27., 26., 28.,
#         28., 28., 28., 29., 28., 28., 29., 28., 28., 29., 28., 28., 28.,
#         29., 28., 28., 29., 28., 28., 28., 27., 28., 28., 29., 28., 27.,
#         28., 28., 28.]])

# %%
for i in range(2):
    pred_plot(scaler_x.inverse_transform(X_test[:i+1]),
              scaler_y.inverse_transform(y_test[:i+1]),
              scaler_y.inverse_transform(model.predict(X_test[:i+1])),
              i)

# %% [markdown]
# # Testing and Experiments

# %%
for i in range(5):
    print('test index:', i)
    true = scaler_x.inverse_transform(X_test[i:i+1])[0][(N_TIME - 1) * 10:(N_TIME - 1) * 10 + 10]
    print('True: ', true)

    ynew= model.predict(X_test)
    predict = scaler_y.inverse_transform(ynew[i:i+1])[0]
    print('Predicted: ', predict)

    result = []
    for j in range(len(true)):
        result.append([true[j], " - ", predict[j], " = ", abs(true[j] - predict[j])])
    
    for j in result:
        print(j)
    print("\n")
# Out:
# test index: 0
# True:  [28. 27. 27. 28. 28. 28. 27. 28. 28. 28.]
# Predicted:  [28.309061 27.334747 27.693579 28.038485 28.453144 27.79826  27.424221
#  28.330235 28.153505 28.258759]
# [28.0, ' - ', 28.309061, ' = ', 0.30906105041503906]
# [27.0, ' - ', 27.334747, ' = ', 0.334747314453125]
# [27.0, ' - ', 27.693579, ' = ', 0.6935787200927734]
# [27.999999999999996, ' - ', 28.038485, ' = ', 0.038484573364261365]
# [28.0, ' - ', 28.453144, ' = ', 0.4531440734863281]
# [28.0, ' - ', 27.79826, ' = ', 0.20174026489257812]
# [27.0, ' - ', 27.424221, ' = ', 0.4242210388183594]
# [28.0, ' - ', 28.330235, ' = ', 0.3302345275878906]
# [28.0, ' - ', 28.153505, ' = ', 0.1535053253173828]
# [28.0, ' - ', 28.258759, ' = ', 0.258758544921875]
#
#
# test index: 1
# True:  [28. 27. 28. 28. 29. 28. 27. 28. 28. 28.]
# Predicted:  [28.262547 27.641186 27.88532  28.081024 28.601269 27.890013 27.67809
#  28.617105 28.21972  28.385174]
# [28.0, ' - ', 28.262547, ' = ', 0.2625465393066406]
# [27.0, ' - ', 27.641186, ' = ', 0.6411857604980469]
# [28.0, ' - ', 27.88532, ' = ', 0.11467933654785156]
# [27.999999999999996, ' - ', 28.081024, ' = ', 0.08102416992187855]
# [29.000000000000004, ' - ', 28.601269, ' = ', 0.3987312316894567]
# [28.0, ' - ', 27.890013, ' = ', 0.10998725891113281]
# [27.0, ' - ', 27.67809, ' = ', 0.6780891418457031]
# [28.0, ' - ', 28.617105, ' = ', 0.6171054840087891]
# [28.0, ' - ', 28.21972, ' = ', 0.21972084045410156]
# [28.0, ' - ', 28.385174, ' = ', 0.3851737976074219]
#
#
# test index: 2
# True:  [27. 26. 26. 26. 27. 26. 26. 27. 27. 27.]
# Predicted:  [27.00346  26.263369 26.483095 26.647915 27.036858 26.53976  26.243122
#  27.32201  26.780079 26.786993]
# [27.0, ' - ', 27.00346, ' = ', 0.003459930419921875]
# [26.0, ' - ', 26.263369, ' = ', 0.2633686065673828]
# [26.0, ' - ', 26.483095, ' = ', 0.4830951690673828]
# [26.0, ' - ', 26.647915, ' = ', 0.6479148864746094]
# [27.0, ' - ', 27.036858, ' = ', 0.03685760498046875]
# [26.0, ' - ', 26.53976, ' = ', 0.5397605895996094]
# [26.0, ' - ', 26.243122, ' = ', 0.24312210083007812]
# [27.0, ' - ', 27.32201, ' = ', 0.3220100402832031]
# [27.0, ' - ', 26.780079, ' = ', 0.21992111206054688]
# [27.0, ' - ', 26.786993, ' = ', 0.21300697326660156]
#
#
# test index: 3
# True:  [25. 25. 25. 25. 25. 25. 25. 26. 25. 25.]
# Predicted:  [25.51131  25.024536 25.195175 25.295801 25.420408 25.01055  24.895302
#  26.05891  25.270323 25.33886 ]
# [25.0, ' - ', 25.51131, ' = ', 0.5113105773925781]
# [25.0, ' - ', 25.024536, ' = ', 0.0245361328125]
# [25.0, ' - ', 25.195175, ' = ', 0.1951751708984375]
# [25.0, ' - ', 25.295801, ' = ', 0.29580116271972656]
# [25.0, ' - ', 25.420408, ' = ', 0.4204082489013672]
# [25.0, ' - ', 25.01055, ' = ', 0.010549545288085938]
# [25.0, ' - ', 24.895302, ' = ', 0.10469818115234375]
# [26.0, ' - ', 26.05891, ' = ', 0.058910369873046875]
# [25.0, ' - ', 25.270323, ' = ', 0.2703227996826172]
# [25.0, ' - ', 25.33886, ' = ', 0.33885955810546875]
#
#
# test index: 4
# True:  [25. 25. 25. 26. 26. 25. 25. 27. 26. 26.]
# Predicted:  [25.799809 25.03396  25.230743 25.647928 26.013054 25.160398 25.097733
#  26.221912 25.782171 25.847198]
# [25.0, ' - ', 25.799809, ' = ', 0.7998085021972656]
# [25.0, ' - ', 25.03396, ' = ', 0.03396034240722656]
# [25.0, ' - ', 25.230743, ' = ', 0.230743408203125]
# [26.0, ' - ', 25.647928, ' = ', 0.35207176208496094]
# [26.0, ' - ', 26.013054, ' = ', 0.01305389404296875]
# [25.0, ' - ', 25.160398, ' = ', 0.1603984832763672]
# [25.0, ' - ', 25.097733, ' = ', 0.0977325439453125]
# [27.0, ' - ', 26.221912, ' = ', 0.7780876159667969]
# [26.0, ' - ', 25.782171, ' = ', 0.21782875061035156]
# [26.0, ' - ', 25.847198, ' = ', 0.152801513671875]

# %% [markdown]
# # Visualizations

# %%
def plot_train_history(history, title):
  mpl.rcParams['figure.figsize'] = (8, 6)
  mpl.rcParams['axes.grid'] = False
    
  loss = history.history['loss']
  val_loss = history.history['val_loss']
    
  epochs = range(len(loss))

  y = []
  for i in epochs:
        y.append(0)

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.plot(epochs, y, 'g', label='y = 0 axis')
  plt.xlabel('Epochs')
  plt.ylabel('MSE value or Losses')
    
  plt.title(title)
  plt.legend()

  plt.show()

# %%
plot_train_history(fit,
                   'Visualization losses')

# %% [raw]
# mpl.rcParams['figure.figsize'] = (24,18)
# mpl.rcParams['axes.grid'] = False
# uni_data = test_df
# uni_data.index = list(test_df.index.values)
# uni_data.head()
# uni_data.plot(subplots=True)
