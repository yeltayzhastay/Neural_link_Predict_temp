# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense

import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import os

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %%
df1 = pd.read_csv("bef_data_1.csv")
df2 = pd.read_csv("bef_data_2.csv")
df3 = pd.read_csv("bef_data_3.csv")
df4 = pd.read_csv("bef_data_4.csv")
df5 = pd.read_csv("bef_data_5.csv")

#df1 = df1.set_index('time')
#df1.columns = ['Temp1', 'Temp2', 'Temp3', 'Temp4', 'Temp5', 'Temp6', 'Temp7', 'Temp8', 'Temp9', 'Temp10']
#df1

# %%
def shaper(arr, n_time = 1):
    arr = arr.values.tolist()
    shape_list = []
    for i in range(0, len(arr) - n_time, 1):
        time_list = []
        for j in range(n_time):
            time_list +=arr[i + j]
        shape_list.append(time_list)
        
    columns = []
    for i in range((-n_time)+1,1,1):
        columns += ["Temp1_" + str(i), 
                    "Temp2_" + str(i), 
                    "Temp3_" + str(i), 
                    "Temp4_" + str(i), 
                    "Temp5_" + str(i), 
                    "Temp6_" + str(i), 
                    "Temp7_" + str(i), 
                    "Temp8_" + str(i), 
                    "Temp9_" + str(i), 
                    "Temp10_" + str(i),
                    #'cond1_off_' + str(i),
                    #'c1_16h_' + str(i), 
                    #'c1_16l_' + str(i), 
                    #'c1_23h_' + str(i), 
                    #'c1_23l_' + str(i), 
                    #'c1_30h_' + str(i), 
                    #'c1_30l_' + str(i), 
                    #'cond2_off_' + str(i), 
                    #'c2_16h_' + str(i), 
                    #'c2_16l_' + str(i), 
                    #'c2_23h_' + str(i), 
                    #'c2_23l_' + str(i), 
                    #'c2_30h_' + str(i), 
                    #'c2_30l_' + str(i)
                   ]
    
    td = pd.DataFrame(shape_list, columns = columns)
    return td

def union_shaper(df_list, n_time = 1):
    frames = []
    for i in range(len(df_list)):
        df = pd.DataFrame(df_list[i], columns = ["time", "Temp1","Temp2", "Temp3", "Temp4", "Temp5", "Temp6", "Temp7", "Temp8", "Temp9", "Temp10"])
        df = df.set_index('time')
        df.columns = ['Temp1', 'Temp2', 'Temp3', 'Temp4', 'Temp5', 'Temp6', 'Temp7', 'Temp8', 'Temp9', 'Temp10']
        df = shaper(df, n_time)
        
        df['Temp1+1'] = df['Temp1_0'].shift(-1)
        df['Temp2+1'] = df['Temp2_0'].shift(-1)
        df['Temp3+1'] = df['Temp3_0'].shift(-1)
        df['Temp4+1'] = df['Temp4_0'].shift(-1)
        df['Temp5+1'] = df['Temp5_0'].shift(-1)
        df['Temp6+1'] = df['Temp6_0'].shift(-1)
        df['Temp7+1'] = df['Temp7_0'].shift(-1)
        df['Temp8+1'] = df['Temp8_0'].shift(-1)
        df['Temp9+1'] = df['Temp9_0'].shift(-1)
        df['Temp10+1'] = df['Temp10_0'].shift(-1)

        df['Temp1+1'].fillna(24, inplace=True)
        df['Temp2+1'].fillna(24, inplace=True)
        df['Temp3+1'].fillna(24, inplace=True)
        df['Temp4+1'].fillna(24, inplace=True)
        df['Temp5+1'].fillna(24, inplace=True)
        df['Temp6+1'].fillna(24, inplace=True)
        df['Temp7+1'].fillna(24, inplace=True)
        df['Temp8+1'].fillna(24, inplace=True)
        df['Temp9+1'].fillna(24, inplace=True)
        df['Temp10+1'].fillna(24, inplace=True)
        frames.append(df)
    return pd.concat(frames, ignore_index=True)

# %%
N_TIME = 24
df = union_shaper([df1, df2, df3, df4, df5], N_TIME)
df
# Out:
#      Temp1_-23  Temp2_-23  Temp3_-23  Temp4_-23  Temp5_-23  Temp6_-23  \
# 0           28         27         27         27         28         27
# 1           27         27         27         27         28         27
# 2           27         27         27         27         27         26
# 3           27         26         26         27         27         26
# 4           27         26         26         26         27         26
# ..         ...        ...        ...        ...        ...        ...
# 881         22         22         22         22         22         22
# 882         22         22         22         22         22         22
# 883         22         22         22         22         22         22
# 884         22         22         22         22         22         21
# 885         22         21         21         22         22         21
#
#      Temp7_-23  Temp8_-23  Temp9_-23  Temp10_-23  ...  Temp1+1  Temp2+1  \
# 0           27         28         27          27  ...     25.0     24.0
# 1           27         28         27          27  ...     25.0     25.0
# 2           26         27         27          27  ...     25.0     25.0
# 3           26         27         27          27  ...     25.0     24.0
# 4           26         27         27          27  ...     25.0     24.0
# ..         ...        ...        ...         ...  ...      ...      ...
# 881         22         22         22          22  ...     25.0     24.0
# 882         22         22         22          22  ...     25.0     24.0
# 883         21         22         22          22  ...     25.0     24.0
# 884         21         22         22          22  ...     25.0     24.0
# 885         21         22         22          22  ...     24.0     24.0
#
#      Temp3+1  Temp4+1  Temp5+1  Temp6+1  Temp7+1  Temp8+1  Temp9+1  Temp10+1
# 0       25.0     25.0     25.0     24.0     24.0     25.0     25.0      25.0
# 1       25.0     25.0     25.0     25.0     24.0     25.0     25.0      25.0
# 2       25.0     25.0     25.0     25.0     25.0     26.0     25.0      25.0
# 3       25.0     25.0     25.0     24.0     25.0     25.0     25.0      25.0
# 4       25.0     25.0     25.0     24.0     24.0     25.0     25.0      25.0
# ..       ...      ...      ...      ...      ...      ...      ...       ...
# 881     24.0     24.0     25.0     24.0     24.0     25.0     25.0      25.0
# 882     24.0     25.0     25.0     24.0     25.0     25.0     25.0      25.0
# 883     25.0     25.0     25.0     24.0     25.0     25.0     25.0      25.0
# 884     25.0     25.0     26.0     25.0     25.0     25.0     25.0      25.0
# 885     24.0     24.0     24.0     24.0     24.0     24.0     24.0      24.0
#
# [886 rows x 250 columns]

# %% [raw]
# df['Temp1+1'] = df['Temp1_0'].shift(-1)
# df['Temp2+1'] = df['Temp2_0'].shift(-1)
# df['Temp3+1'] = df['Temp3_0'].shift(-1)
# df['Temp4+1'] = df['Temp4_0'].shift(-1)
# df['Temp5+1'] = df['Temp5_0'].shift(-1)
# df['Temp6+1'] = df['Temp6_0'].shift(-1)
# df['Temp7+1'] = df['Temp7_0'].shift(-1)
# df['Temp8+1'] = df['Temp8_0'].shift(-1)
# df['Temp9+1'] = df['Temp9_0'].shift(-1)
# df['Temp10+1'] = df['Temp10_0'].shift(-1)
#
# df['Temp1+1'].fillna(24, inplace=True)
# df['Temp2+1'].fillna(24, inplace=True)
# df['Temp3+1'].fillna(24, inplace=True)
# df['Temp4+1'].fillna(24, inplace=True)
# df['Temp5+1'].fillna(24, inplace=True)
# df['Temp6+1'].fillna(24, inplace=True)
# df['Temp7+1'].fillna(24, inplace=True)
# df['Temp8+1'].fillna(24, inplace=True)
# df['Temp9+1'].fillna(24, inplace=True)
# df['Temp10+1'].fillna(24, inplace=True)

# %%
x = df.drop(['Temp1+1', 'Temp2+1', 'Temp3+1', 'Temp4+1', 'Temp5+1', 'Temp6+1', 'Temp7+1', 'Temp8+1', 'Temp9+1', 'Temp10+1'], axis = 1)
y = df[['Temp1+1', 'Temp2+1', 'Temp3+1', 'Temp4+1', 'Temp5+1', 'Temp6+1', 'Temp7+1', 'Temp8+1', 'Temp9+1', 'Temp10+1']]

y=np.reshape(y.values, (-1,10))

scaler_x = MinMaxScaler()
print(scaler_x.fit(x))
scaler_y = MinMaxScaler()
print(scaler_y.fit(y))
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %% [markdown]
# # Variants

# %%
X_train = scaler_x.transform(x)
y_train = scaler_y.transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.2)

# %% [raw]
# X_test = scaler_x.transform(x[87:100])
# y_test = scaler_y.transform(y[87:100])

# %% [markdown]
# xscale=scaler_x.transform(x)
# yscale=scaler_y.transform(y)
#
# X_train, X_test, y_train, y_test = train_test_split(xscale, yscale, train_size = 1)

# %% [markdown]
# # Neural Link

# %%
model = Sequential()
model.add(Dense(256, input_dim=10 * N_TIME, kernel_initializer='normal', activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='linear'))
model.summary()
# Use a custom metricfunction

model.compile(loss='mse', optimizer='adam')

fit = model.fit(X_train, y_train, epochs=100,  verbose=1, validation_split=0.5)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               61696
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 198,410
# Trainable params: 198,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0636 - val_loss: 0.0194
# Epoch 2/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0148 - val_loss: 0.0126
# Epoch 3/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0090
# Epoch 4/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 5/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0080
# Epoch 6/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0048 - val_loss: 0.0096
# Epoch 7/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 0.0079
# Epoch 8/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 0.0106
# Epoch 9/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0077
# Epoch 10/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0080
# Epoch 11/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0042 - val_loss: 0.0068
# Epoch 12/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0035 - val_loss: 0.0064
# Epoch 13/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0069
# Epoch 14/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 0.0064
# Epoch 15/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 0.0069
# Epoch 16/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.0067
# Epoch 17/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0069
# Epoch 18/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 0.0077
# Epoch 19/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0038 - val_loss: 0.0078
# Epoch 20/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0037 - val_loss: 0.0092
# Epoch 21/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0097
# Epoch 22/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0065 - val_loss: 0.0087
# Epoch 23/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0057 - val_loss: 0.0085
# Epoch 24/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0043 - val_loss: 0.0075
# Epoch 25/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0065
# Epoch 26/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0079
# Epoch 27/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 0.0064
# Epoch 28/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0029 - val_loss: 0.0064
# Epoch 29/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0028 - val_loss: 0.0064
# Epoch 30/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.0063
# Epoch 31/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 0.0065
# Epoch 32/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0028 - val_loss: 0.0062
# Epoch 33/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0031 - val_loss: 0.0074
# Epoch 34/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0066
# Epoch 35/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 36/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0062
# Epoch 37/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0065
# Epoch 38/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 0.0066
# Epoch 39/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 40/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 0.0062
# Epoch 41/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0062
# Epoch 42/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.0063
# Epoch 43/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0029 - val_loss: 0.0067
# Epoch 44/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 0.0065
# Epoch 45/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0073
# Epoch 46/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0063
# Epoch 47/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 0.0071
# Epoch 48/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0030 - val_loss: 0.0064
# Epoch 49/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 0.0072
# Epoch 50/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0027 - val_loss: 0.0065
# Epoch 51/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 0.0065
# Epoch 52/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0066
# Epoch 53/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0075
# Epoch 54/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0026 - val_loss: 0.0064
# Epoch 55/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0073
# Epoch 56/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0027 - val_loss: 0.0070
# Epoch 57/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 58/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0026 - val_loss: 0.0061
# Epoch 59/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0025 - val_loss: 0.0061
# Epoch 60/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0071
# Epoch 61/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0061
# Epoch 62/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 0.0071
# Epoch 63/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0065
# Epoch 64/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 0.0064
# Epoch 65/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0063
# Epoch 66/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0063
# Epoch 67/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 0.0065
# Epoch 68/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0023 - val_loss: 0.0062
# Epoch 69/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 0.0063
# Epoch 70/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0023 - val_loss: 0.0067
# Epoch 71/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0072
# Epoch 72/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.0122
# Epoch 73/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0060
# Epoch 74/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 0.0064
# Epoch 75/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 76/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0067
# Epoch 77/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0117
# Epoch 78/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0043 - val_loss: 0.0061
# Epoch 79/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 0.0068
# Epoch 80/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0100
# Epoch 81/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0061
# Epoch 82/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0076
# Epoch 83/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 84/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: 0.0067
# Epoch 85/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 0.0069
# Epoch 86/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 0.0062
# Epoch 87/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 0.0089
# Epoch 88/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0073
# Epoch 89/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 0.0095
# Epoch 90/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0036 - val_loss: 0.0063
# Epoch 91/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0066
# Epoch 92/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 0.0068
# Epoch 93/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 0.0065
# Epoch 94/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0061
# Epoch 95/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 0.0065
# Epoch 96/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0023 - val_loss: 0.0065
# Epoch 97/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0025 - val_loss: 0.0067
# Epoch 98/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0028 - val_loss: 0.0074
# Epoch 99/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0062
# Epoch 100/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0022 - val_loss: 0.0091

# %% [raw]
# scores = model.evaluate(X_test, y_test, verbose=1)
# print("Доля верных ответов на тестовых данных, в процентах:", round(scores[1] * 100, 4))

# %%
def pred_plot(x, y, p, index):
    mpl.rcParams['figure.figsize'] = (4, 3)
    mpl.rcParams['axes.grid'] = False
    
    history = np.transpose(np.reshape(x[index], (-1, 10)))
    
    length = history.shape[1]
    #np.reshape(X, (-1, 10))[-1].tolist()
    
    real = np.transpose(np.array(y[index]))
    
    pred = np.transpose(np.array(p[index]))
    
    for i in range(10):
        percent = (history[i].max() - history[i].min())
        result = (percent-abs(real[i] - pred[i]))/percent
        
        plt.plot(range(length), history[i], label='History')
        plt.plot(length, real[i], 'bo', label='Real')
        plt.plot(length, pred[i], 'rx', label='Predicted')
        plt.xlabel('Time')
        plt.ylabel('Temperature value')
        plt.legend(loc='upper left')
        plt.title('index: ' + str(index) + ', temp: ' + str(i+1) + '\npercent: ' + str(result*100))
        plt.show()

# %%
scaler_x.inverse_transform(X_test[:2])
# Out:
# array([[28., 28., 28., 28., 28., 28., 28., 28., 28., 28., 29., 28., 28.,
#         29., 29., 28., 28., 29., 29., 29., 29., 29., 29., 29., 29., 29.,
#         29., 30., 29., 29., 30., 29., 30., 30., 30., 29., 29., 30., 30.,
#         30., 31., 30., 30., 30., 31., 30., 30., 31., 30., 31., 31., 30.,
#         31., 31., 31., 31., 31., 31., 31., 31., 32., 31., 31., 31., 32.,
#         31., 31., 32., 32., 32., 30., 29., 29., 30., 30., 30., 29., 31.,
#         30., 30., 27., 26., 26., 27., 27., 26., 26., 27., 26., 27., 27.,
#         26., 26., 27., 27., 26., 26., 27., 26., 26., 26., 25., 25., 26.,
#         26., 25., 25., 26., 25., 25., 26., 25., 25., 26., 26., 25., 25.,
#         26., 25., 25., 26., 25., 25., 26., 26., 25., 25., 26., 25., 25.,
#         26., 26., 26., 27., 27., 26., 26., 27., 27., 27., 26., 26., 26.,
#         27., 27., 26., 26., 27., 27., 27., 27., 26., 26., 27., 27., 26.,
#         26., 27., 27., 27., 27., 26., 27., 27., 28., 26., 27., 28., 27.,
#         27., 27., 26., 27., 27., 28., 27., 27., 28., 27., 27., 27., 26.,
#         27., 27., 28., 27., 27., 28., 27., 27., 27., 26., 27., 27., 28.,
#         27., 27., 28., 28., 27., 27., 26., 26., 27., 27., 26., 27., 28.,
#         27., 27., 26., 26., 26., 26., 27., 26., 26., 27., 26., 26., 26.,
#         26., 26., 26., 27., 26., 26., 27., 26., 26., 26., 25., 26., 26.,
#         26., 25., 25., 27., 26., 26.],
#        [26., 25., 25., 26., 26., 25., 25., 26., 25., 25., 26., 25., 25.,
#         26., 26., 25., 25., 26., 25., 25., 26., 25., 25., 26., 26., 25.,
#         25., 26., 25., 25., 26., 26., 26., 27., 27., 26., 26., 27., 27.,
#         27., 26., 26., 26., 27., 27., 26., 26., 27., 27., 27., 27., 26.,
#         26., 27., 27., 26., 26., 27., 27., 27., 27., 26., 27., 27., 28.,
#         26., 27., 28., 27., 27., 27., 26., 27., 27., 28., 27., 27., 28.,
#         27., 27., 27., 26., 27., 27., 28., 27., 27., 28., 27., 27., 27.,
#         26., 27., 27., 28., 27., 27., 28., 28., 27., 27., 26., 26., 27.,
#         27., 26., 27., 28., 27., 27., 26., 26., 26., 26., 27., 26., 26.,
#         27., 26., 26., 26., 26., 26., 26., 27., 26., 26., 27., 26., 26.,
#         26., 25., 26., 26., 26., 25., 25., 27., 26., 26., 26., 25., 25.,
#         26., 26., 25., 25., 26., 26., 26., 26., 25., 25., 26., 26., 25.,
#         25., 26., 26., 26., 26., 25., 25., 26., 26., 25., 25., 26., 26.,
#         25., 26., 25., 25., 25., 26., 25., 25., 26., 26., 26., 26., 25.,
#         25., 25., 26., 25., 25., 26., 25., 25., 25., 25., 25., 25., 26.,
#         25., 25., 26., 25., 25., 25., 25., 25., 25., 26., 25., 25., 26.,
#         25., 25., 25., 25., 25., 25., 25., 25., 25., 26., 26., 25., 25.,
#         25., 25., 25., 25., 25., 24., 25., 25., 25., 25., 25., 25., 25.,
#         25., 25., 24., 26., 25., 25.]])

# %%
for i in range(2):
    pred_plot(scaler_x.inverse_transform(X_test[:i+1]),
              scaler_y.inverse_transform(y_test[:i+1]),
              scaler_y.inverse_transform(model.predict(X_test[:i+1])),
              i)

# %% [markdown]
# # Testing and Experiments

# %%
for i in range(5):
    print('test index:', i)
    true = scaler_x.inverse_transform(X_test[i:i+1])[0][(N_TIME - 1) * 10:(N_TIME - 1) * 10 + 10]
    print('True: ', true)

    ynew= model.predict(X_test)
    predict = scaler_y.inverse_transform(ynew[i:i+1])[0]
    print('Predicted: ', predict)

    result = []
    for j in range(len(true)):
        result.append([true[j], " - ", predict[j], " = ", abs(true[j] - predict[j])])
    
    for j in result:
        print(j)
    print("\n")
# Out:
# test index: 0
# True:  [26. 25. 26. 26. 26. 25. 25. 27. 26. 26.]
# Predicted:  [26.461164 26.169653 25.727846 26.26932  26.892597 26.14548  25.956474
#  26.696201 26.325045 26.30824 ]
# [26.0, ' - ', 26.461164, ' = ', 0.4611644744873047]
# [25.0, ' - ', 26.169653, ' = ', 1.1696529388427734]
# [26.0, ' - ', 25.727846, ' = ', 0.2721538543701172]
# [26.0, ' - ', 26.26932, ' = ', 0.2693195343017578]
# [26.0, ' - ', 26.892597, ' = ', 0.8925971984863281]
# [25.0, ' - ', 26.14548, ' = ', 1.1454792022705078]
# [25.0, ' - ', 25.956474, ' = ', 0.9564743041992188]
# [27.0, ' - ', 26.696201, ' = ', 0.3037986755371094]
# [26.0, ' - ', 26.325045, ' = ', 0.3250446319580078]
# [26.0, ' - ', 26.30824, ' = ', 0.3082408905029297]
#
#
# test index: 1
# True:  [25. 25. 25. 25. 25. 25. 24. 26. 25. 25.]
# Predicted:  [25.470354 25.121    25.044056 25.261799 25.756577 25.266874 24.920166
#  26.207369 25.460804 25.410812]
# [25.0, ' - ', 25.470354, ' = ', 0.4703540802001953]
# [25.0, ' - ', 25.121, ' = ', 0.12100028991699219]
# [25.0, ' - ', 25.044056, ' = ', 0.044055938720703125]
# [25.0, ' - ', 25.261799, ' = ', 0.2617988586425781]
# [25.0, ' - ', 25.756577, ' = ', 0.7565765380859375]
# [25.0, ' - ', 25.266874, ' = ', 0.2668743133544922]
# [24.000000000000004, ' - ', 24.920166, ' = ', 0.9201660156249964]
# [26.0, ' - ', 26.207369, ' = ', 0.2073688507080078]
# [25.0, ' - ', 25.460804, ' = ', 0.4608039855957031]
# [25.0, ' - ', 25.410812, ' = ', 0.4108123779296875]
#
#
# test index: 2
# True:  [23. 22. 23. 23. 23. 22. 22. 24. 23. 23.]
# Predicted:  [23.39405  22.700401 22.93055  23.108181 23.497925 22.800789 22.679268
#  23.884712 23.30635  23.364666]
# [23.0, ' - ', 23.39405, ' = ', 0.39405059814453125]
# [22.0, ' - ', 22.700401, ' = ', 0.7004013061523438]
# [23.0, ' - ', 22.93055, ' = ', 0.06945037841796875]
# [23.0, ' - ', 23.108181, ' = ', 0.10818099975585938]
# [23.0, ' - ', 23.497925, ' = ', 0.4979248046875]
# [22.0, ' - ', 22.800789, ' = ', 0.8007888793945312]
# [22.0, ' - ', 22.679268, ' = ', 0.6792678833007812]
# [24.000000000000004, ' - ', 23.884712, ' = ', 0.1152877807617223]
# [23.0, ' - ', 23.30635, ' = ', 0.3063507080078125]
# [23.0, ' - ', 23.364666, ' = ', 0.3646659851074219]
#
#
# test index: 3
# True:  [28. 27. 28. 28. 29. 28. 28. 29. 28. 28.]
# Predicted:  [28.5437   27.857683 27.928402 28.562239 28.94039  27.823275 27.78634
#  29.176666 28.553814 28.707253]
# [28.0, ' - ', 28.5437, ' = ', 0.5436992645263672]
# [27.0, ' - ', 27.857683, ' = ', 0.8576831817626953]
# [28.0, ' - ', 27.928402, ' = ', 0.07159805297851562]
# [27.999999999999996, ' - ', 28.562239, ' = ', 0.5622386932373082]
# [29.000000000000004, ' - ', 28.94039, ' = ', 0.059610366821292615]
# [28.0, ' - ', 27.823275, ' = ', 0.1767253875732422]
# [28.0, ' - ', 27.78634, ' = ', 0.21365928649902344]
# [29.000000000000004, ' - ', 29.176666, ' = ', 0.17666625976562145]
# [28.0, ' - ', 28.553814, ' = ', 0.5538139343261719]
# [28.0, ' - ', 28.707253, ' = ', 0.7072525024414062]
#
#
# test index: 4
# True:  [31. 30. 30. 31. 31. 30. 30. 31. 31. 31.]
# Predicted:  [31.644016 31.06588  31.010277 31.608027 32.142086 31.143154 31.083916
#  31.810722 31.800005 31.802988]
# [31.0, ' - ', 31.644016, ' = ', 0.6440162658691406]
# [30.0, ' - ', 31.06588, ' = ', 1.0658798217773438]
# [30.0, ' - ', 31.010277, ' = ', 1.0102767944335938]
# [31.0, ' - ', 31.608027, ' = ', 0.6080265045166016]
# [31.0, ' - ', 32.142086, ' = ', 1.1420860290527344]
# [30.0, ' - ', 31.143154, ' = ', 1.1431541442871094]
# [30.0, ' - ', 31.083916, ' = ', 1.0839157104492188]
# [31.0, ' - ', 31.810722, ' = ', 0.8107223510742188]
# [31.0, ' - ', 31.800005, ' = ', 0.8000049591064453]
# [31.0, ' - ', 31.802988, ' = ', 0.8029880523681641]

# %% [markdown]
# # Visualizations

# %%
def plot_train_history(history, title):
  mpl.rcParams['figure.figsize'] = (8, 6)
  mpl.rcParams['axes.grid'] = False
    
  loss = history.history['loss']
  val_loss = history.history['val_loss']
    
  epochs = range(len(loss))

  y = []
  for i in epochs:
        y.append(0)

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.plot(epochs, y, 'g', label='y = 0 axis')
  plt.xlabel('Epochs')
  plt.ylabel('MSE value or Losses')
    
  plt.title(title)
  plt.legend()

  plt.show()

# %%
plot_train_history(fit,
                   'Visualization losses')

# %% [raw]
# mpl.rcParams['figure.figsize'] = (24,18)
# mpl.rcParams['axes.grid'] = False
# uni_data = test_df
# uni_data.index = list(test_df.index.values)
# uni_data.head()
# uni_data.plot(subplots=True)
