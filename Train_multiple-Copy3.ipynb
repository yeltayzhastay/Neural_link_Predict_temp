# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense

import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import os

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %%
df1 = pd.read_csv("bef_data_1.csv")
df2 = pd.read_csv("bef_data_2.csv")
df3 = pd.read_csv("bef_data_3.csv")
df4 = pd.read_csv("bef_data_4.csv")
df5 = pd.read_csv("bef_data_5.csv")

#df1 = df1.set_index('time')
#df1.columns = ['Temp1', 'Temp2', 'Temp3', 'Temp4', 'Temp5', 'Temp6', 'Temp7', 'Temp8', 'Temp9', 'Temp10']
#df1

# %%
def shaper(arr, n_time = 1):
    arr = arr.values.tolist()
    shape_list = []
    for i in range(0, len(arr) - n_time, 1):
        time_list = []
        for j in range(n_time):
            time_list +=arr[i + j]
        shape_list.append(time_list)
        
    columns = []
    for i in range((-n_time)+1,1,1):
        columns += ["Temp1_" + str(i), 
                    "Temp2_" + str(i), 
                    "Temp3_" + str(i), 
                    "Temp4_" + str(i), 
                    "Temp5_" + str(i), 
                    "Temp6_" + str(i), 
                    "Temp7_" + str(i), 
                    "Temp8_" + str(i), 
                    "Temp9_" + str(i), 
                    "Temp10_" + str(i),
                    #'cond1_off_' + str(i),
                    #'c1_16h_' + str(i), 
                    #'c1_16l_' + str(i), 
                    #'c1_23h_' + str(i), 
                    #'c1_23l_' + str(i), 
                    #'c1_30h_' + str(i), 
                    #'c1_30l_' + str(i), 
                    #'cond2_off_' + str(i), 
                    #'c2_16h_' + str(i), 
                    #'c2_16l_' + str(i), 
                    #'c2_23h_' + str(i), 
                    #'c2_23l_' + str(i), 
                    #'c2_30h_' + str(i), 
                    #'c2_30l_' + str(i)
                   ]
    
    td = pd.DataFrame(shape_list, columns = columns)
    return td

def union_shaper(df_list, n_time = 1):
    frames = []
    for i in range(len(df_list)):
        df = pd.DataFrame(df_list[i], columns = ["time", "Temp1","Temp2", "Temp3", "Temp4", "Temp5", "Temp6", "Temp7", "Temp8", "Temp9", "Temp10"])
        df = df.set_index('time')
        df.columns = ['Temp1', 'Temp2', 'Temp3', 'Temp4', 'Temp5', 'Temp6', 'Temp7', 'Temp8', 'Temp9', 'Temp10']
        df = shaper(df, n_time)
        
        df['Temp1+1'] = df['Temp1_0'].shift(-1)
        df['Temp2+1'] = df['Temp2_0'].shift(-1)
        df['Temp3+1'] = df['Temp3_0'].shift(-1)
        df['Temp4+1'] = df['Temp4_0'].shift(-1)
        df['Temp5+1'] = df['Temp5_0'].shift(-1)
        df['Temp6+1'] = df['Temp6_0'].shift(-1)
        df['Temp7+1'] = df['Temp7_0'].shift(-1)
        df['Temp8+1'] = df['Temp8_0'].shift(-1)
        df['Temp9+1'] = df['Temp9_0'].shift(-1)
        df['Temp10+1'] = df['Temp10_0'].shift(-1)

        df['Temp1+1'].fillna(24, inplace=True)
        df['Temp2+1'].fillna(24, inplace=True)
        df['Temp3+1'].fillna(24, inplace=True)
        df['Temp4+1'].fillna(24, inplace=True)
        df['Temp5+1'].fillna(24, inplace=True)
        df['Temp6+1'].fillna(24, inplace=True)
        df['Temp7+1'].fillna(24, inplace=True)
        df['Temp8+1'].fillna(24, inplace=True)
        df['Temp9+1'].fillna(24, inplace=True)
        df['Temp10+1'].fillna(24, inplace=True)
        frames.append(df)
    return pd.concat(frames, ignore_index=True)

# %%
N_TIME = 4
df = union_shaper([df1, df2, df3, df4, df5], N_TIME)
df
# Out:
#      Temp1_-3  Temp2_-3  Temp3_-3  Temp4_-3  Temp5_-3  Temp6_-3  Temp7_-3  \
# 0          28        27        27        27        28        27        27
# 1          27        27        27        27        28        27        27
# 2          27        27        27        27        27        26        26
# 3          27        26        26        27        27        26        26
# 4          27        26        26        26        27        26        26
# ..        ...       ...       ...       ...       ...       ...       ...
# 981        24        23        24        24        24        23        24
# 982        25        24        24        25        25        24        24
# 983        25        24        24        24        25        24        24
# 984        25        24        24        25        25        24        24
# 985        25        24        24        24        25        24        24
#
#      Temp8_-3  Temp9_-3  Temp10_-3  ...  Temp1+1  Temp2+1  Temp3+1  Temp4+1  \
# 0          28        27         27  ...     27.0     26.0     26.0     26.0
# 1          28        27         27  ...     27.0     26.0     26.0     26.0
# 2          27        27         27  ...     27.0     26.0     26.0     26.0
# 3          27        27         27  ...     26.0     26.0     26.0     26.0
# 4          27        27         27  ...     26.0     26.0     26.0     26.0
# ..        ...       ...        ...  ...      ...      ...      ...      ...
# 981        24        24         24  ...     25.0     24.0     24.0     24.0
# 982        25        24         25  ...     25.0     24.0     24.0     25.0
# 983        25        25         25  ...     25.0     24.0     25.0     25.0
# 984        25        25         25  ...     25.0     24.0     25.0     25.0
# 985        25        25         25  ...     24.0     24.0     24.0     24.0
#
#      Temp5+1  Temp6+1  Temp7+1  Temp8+1  Temp9+1  Temp10+1
# 0       27.0     26.0     26.0     27.0     27.0      27.0
# 1       27.0     26.0     26.0     27.0     27.0      27.0
# 2       27.0     26.0     26.0     27.0     27.0      27.0
# 3       27.0     26.0     26.0     27.0     26.0      27.0
# 4       27.0     26.0     26.0     27.0     26.0      27.0
# ..       ...      ...      ...      ...      ...       ...
# 981     25.0     24.0     24.0     25.0     25.0      25.0
# 982     25.0     24.0     25.0     25.0     25.0      25.0
# 983     25.0     24.0     25.0     25.0     25.0      25.0
# 984     26.0     25.0     25.0     25.0     25.0      25.0
# 985     24.0     24.0     24.0     24.0     24.0      24.0
#
# [986 rows x 50 columns]

# %% [raw]
# df['Temp1+1'] = df['Temp1_0'].shift(-1)
# df['Temp2+1'] = df['Temp2_0'].shift(-1)
# df['Temp3+1'] = df['Temp3_0'].shift(-1)
# df['Temp4+1'] = df['Temp4_0'].shift(-1)
# df['Temp5+1'] = df['Temp5_0'].shift(-1)
# df['Temp6+1'] = df['Temp6_0'].shift(-1)
# df['Temp7+1'] = df['Temp7_0'].shift(-1)
# df['Temp8+1'] = df['Temp8_0'].shift(-1)
# df['Temp9+1'] = df['Temp9_0'].shift(-1)
# df['Temp10+1'] = df['Temp10_0'].shift(-1)
#
# df['Temp1+1'].fillna(24, inplace=True)
# df['Temp2+1'].fillna(24, inplace=True)
# df['Temp3+1'].fillna(24, inplace=True)
# df['Temp4+1'].fillna(24, inplace=True)
# df['Temp5+1'].fillna(24, inplace=True)
# df['Temp6+1'].fillna(24, inplace=True)
# df['Temp7+1'].fillna(24, inplace=True)
# df['Temp8+1'].fillna(24, inplace=True)
# df['Temp9+1'].fillna(24, inplace=True)
# df['Temp10+1'].fillna(24, inplace=True)

# %%
x = df.drop(['Temp1+1', 'Temp2+1', 'Temp3+1', 'Temp4+1', 'Temp5+1', 'Temp6+1', 'Temp7+1', 'Temp8+1', 'Temp9+1', 'Temp10+1'], axis = 1)
y = df[['Temp1+1', 'Temp2+1', 'Temp3+1', 'Temp4+1', 'Temp5+1', 'Temp6+1', 'Temp7+1', 'Temp8+1', 'Temp9+1', 'Temp10+1']]

y=np.reshape(y.values, (-1,10))

scaler_x = MinMaxScaler()
print(scaler_x.fit(x))
scaler_y = MinMaxScaler()
print(scaler_y.fit(y))
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %% [markdown]
# # Variants

# %%
X_train = scaler_x.transform(x)
y_train = scaler_y.transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.1)

# %% [raw]
# X_test = scaler_x.transform(x[87:100])
# y_test = scaler_y.transform(y[87:100])

# %% [markdown]
# xscale=scaler_x.transform(x)
# yscale=scaler_y.transform(y)
#
# X_train, X_test, y_train, y_test = train_test_split(xscale, yscale, train_size = 1)

# %% [markdown]
# # Neural Link

# %%
model = Sequential()
model.add(Dense(1024, input_dim=10 * N_TIME, kernel_initializer='normal', activation='relu'))
model.add(Dense(2048, activation='relu'))
model.add(Dense(10, activation='linear'))
model.summary()
# Use a custom metricfunction

model.compile(loss='mse', optimizer='adam')

fit = model.fit(X_train, y_train, epochs=100,  verbose=1, validation_split=0.5)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              41984
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              2099200
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 2,161,674
# Trainable params: 2,161,674
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 14/14 [==============================] - 1s 76ms/step - loss: 0.0352 - val_loss: 0.0083
# Epoch 2/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0056 - val_loss: 0.0046
# Epoch 3/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 4/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 5/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 6/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0045 - val_loss: 0.0057
# Epoch 7/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0050 - val_loss: 0.0064
# Epoch 8/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0050 - val_loss: 0.0044
# Epoch 9/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 10/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0037 - val_loss: 0.0041
# Epoch 11/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 12/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 13/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 14/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 15/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 16/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0037 - val_loss: 0.0053
# Epoch 17/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0041 - val_loss: 0.0055
# Epoch 18/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 19/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0034 - val_loss: 0.0041
# Epoch 20/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 21/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0037 - val_loss: 0.0055
# Epoch 22/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0046 - val_loss: 0.0042
# Epoch 23/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 24/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 25/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 26/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0041 - val_loss: 0.0044
# Epoch 27/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 28/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0050 - val_loss: 0.0058
# Epoch 29/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 30/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0034 - val_loss: 0.0039
# Epoch 31/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 32/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0033 - val_loss: 0.0042
# Epoch 33/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 34/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 35/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 36/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 37/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 38/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 39/100
# 14/14 [==============================] - ETA: 0s - loss: 0.003 - 0s 27ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 40/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0037 - val_loss: 0.0041
# Epoch 41/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 42/100
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 43/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0031 - val_loss: 0.0037
# Epoch 44/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 45/100
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0034 - val_loss: 0.0044
# Epoch 46/100
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0037 - val_loss: 0.0065
# Epoch 47/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 48/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 49/100
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0032 - val_loss: 0.0041
# Epoch 50/100
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 51/100
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 52/100
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 53/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 54/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0034 - val_loss: 0.0052
# Epoch 55/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0039 - val_loss: 0.0055
# Epoch 56/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0043 - val_loss: 0.0050
# Epoch 57/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 58/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0034 - val_loss: 0.0039
# Epoch 59/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0032 - val_loss: 0.0041
# Epoch 60/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0032 - val_loss: 0.0040
# Epoch 61/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 62/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 63/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 64/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0034 - val_loss: 0.0041
# Epoch 65/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 66/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0035 - val_loss: 0.0062
# Epoch 67/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 68/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 69/100
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 70/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0038 - val_loss: 0.0045
# Epoch 71/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 72/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0031 - val_loss: 0.0046
# Epoch 73/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 74/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 75/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 76/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 77/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0034 - val_loss: 0.0041
# Epoch 78/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 79/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0029 - val_loss: 0.0043
# Epoch 80/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 81/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 82/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 83/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0038 - val_loss: 0.0065
# Epoch 84/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 85/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0032 - val_loss: 0.0043
# Epoch 86/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 87/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0039 - val_loss: 0.0047
# Epoch 88/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0036 - val_loss: 0.0064
# Epoch 89/100
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 90/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0037 - val_loss: 0.0044
# Epoch 91/100
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 92/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 93/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0029 - val_loss: 0.0042
# Epoch 94/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0030 - val_loss: 0.0052
# Epoch 95/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 96/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 97/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0031 - val_loss: 0.0040
# Epoch 98/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0029 - val_loss: 0.0039
# Epoch 99/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0029 - val_loss: 0.0040
# Epoch 100/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0028 - val_loss: 0.0041

# %% [raw]
# scores = model.evaluate(X_test, y_test, verbose=1)
# print("Доля верных ответов на тестовых данных, в процентах:", round(scores[1] * 100, 4))

# %%
def pred_plot(x, y, p, index):
    mpl.rcParams['figure.figsize'] = (4, 3)
    mpl.rcParams['axes.grid'] = False
    
    history = np.transpose(np.reshape(x[index], (-1, 10)))
    
    length = history.shape[1]
    #np.reshape(X, (-1, 10))[-1].tolist()
    
    real = np.transpose(np.array(y[index]))
    
    pred = np.transpose(np.array(p[index]))
    
    for i in range(10):
        percent = (history[i].max() - history[i].min())
        result = (percent-abs(real[i] - pred[i]))/percent
        
        plt.plot(range(length), history[i], label='History')
        plt.plot(length, real[i], 'bo', label='Real')
        plt.plot(length, pred[i], 'rx', label='Predicted')
        plt.xlabel('Time')
        plt.ylabel('Temperature value')
        plt.legend(loc='upper left')
        plt.title('index: ' + str(index) + ', temp: ' + str(i+1) + '\npercent: ' + str(result*100))
        plt.show()

# %%
scaler_x.inverse_transform(X_test[:2])
# Out:
# array([[25., 24., 24., 24., 25., 24., 24., 25., 25., 25., 24., 24., 24.,
#         24., 25., 24., 24., 25., 25., 24., 24., 23., 24., 24., 24., 24.,
#         24., 25., 24., 24., 24., 24., 24., 24., 24., 23., 24., 25., 24.,
#         24.],
#        [26., 25., 26., 26., 26., 25., 25., 26., 26., 26., 26., 25., 26.,
#         26., 26., 25., 25., 26., 26., 26., 25., 25., 25., 25., 25., 25.,
#         24., 26., 25., 25., 25., 25., 25., 25., 25., 25., 24., 26., 25.,
#         25.]])

# %%
for i in range(2):
    pred_plot(scaler_x.inverse_transform(X_test[:i+1]),
              scaler_y.inverse_transform(y_test[:i+1]),
              scaler_y.inverse_transform(model.predict(X_test[:i+1])),
              i)
# Out:
# c:\users\zhastay\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()
# c:\users\zhastay\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()
# c:\users\zhastay\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()
# c:\users\zhastay\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()
# c:\users\zhastay\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()
# c:\users\zhastay\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()
# c:\users\zhastay\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()

# %% [markdown]
# # Testing and Experiments

# %%
for i in range(5):
    print('test index:', i)
    true = scaler_x.inverse_transform(X_test[i:i+1])[0][(N_TIME - 1) * 10:(N_TIME - 1) * 10 + 10]
    print('True: ', true)

    ynew= model.predict(X_test)
    predict = scaler_y.inverse_transform(ynew[i:i+1])[0]
    print('Predicted: ', predict)

    result = []
    for j in range(len(true)):
        result.append([true[j], " - ", predict[j], " = ", abs(true[j] - predict[j])])
    
    for j in result:
        print(j)
    print("\n")
# Out:
# test index: 0
# True:  [24. 24. 24. 24. 24. 23. 24. 25. 24. 24.]
# Predicted:  [24.041386 23.49639  23.707424 23.813692 24.167248 23.44364  23.489487
#  24.37767  23.818676 23.981466]
# [23.999999999999996, ' - ', 24.041386, ' = ', 0.04138565063476918]
# [24.000000000000004, ' - ', 23.49639, ' = ', 0.5036106109619176]
# [24.000000000000004, ' - ', 23.707424, ' = ', 0.2925758361816442]
# [24.0, ' - ', 23.813692, ' = ', 0.1863079071044922]
# [24.000000000000004, ' - ', 24.167248, ' = ', 0.16724777221679332]
# [23.0, ' - ', 23.44364, ' = ', 0.44363975524902344]
# [24.000000000000004, ' - ', 23.489487, ' = ', 0.510513305664066]
# [25.0, ' - ', 24.37767, ' = ', 0.6223297119140625]
# [23.999999999999996, ' - ', 23.818676, ' = ', 0.18132400512694957]
# [23.999999999999996, ' - ', 23.981466, ' = ', 0.01853370666503551]
#
#
# test index: 1
# True:  [25. 25. 25. 25. 25. 25. 24. 26. 25. 25.]
# Predicted:  [25.118551 24.73956  24.929583 25.095108 25.240343 24.619095 24.5337
#  25.61408  25.021626 24.993895]
# [25.0, ' - ', 25.118551, ' = ', 0.11855125427246094]
# [25.0, ' - ', 24.73956, ' = ', 0.2604408264160156]
# [25.0, ' - ', 24.929583, ' = ', 0.07041740417480469]
# [25.0, ' - ', 25.095108, ' = ', 0.0951080322265625]
# [25.0, ' - ', 25.240343, ' = ', 0.2403430938720703]
# [25.0, ' - ', 24.619095, ' = ', 0.3809051513671875]
# [24.000000000000004, ' - ', 24.5337, ' = ', 0.5337009429931605]
# [26.0, ' - ', 25.61408, ' = ', 0.38591957092285156]
# [25.0, ' - ', 25.021626, ' = ', 0.021625518798828125]
# [25.0, ' - ', 24.993895, ' = ', 0.0061054229736328125]
#
#
# test index: 2
# True:  [26. 25. 25. 26. 26. 25. 25. 26. 26. 26.]
# Predicted:  [25.72805  24.996891 25.049065 25.333702 25.866262 24.886024 25.06632
#  25.810677 25.680592 25.617355]
# [26.0, ' - ', 25.72805, ' = ', 0.27194976806640625]
# [25.0, ' - ', 24.996891, ' = ', 0.003108978271484375]
# [25.0, ' - ', 25.049065, ' = ', 0.04906463623046875]
# [26.0, ' - ', 25.333702, ' = ', 0.6662979125976562]
# [26.0, ' - ', 25.866262, ' = ', 0.13373756408691406]
# [25.0, ' - ', 24.886024, ' = ', 0.11397552490234375]
# [25.0, ' - ', 25.06632, ' = ', 0.06632041931152344]
# [26.0, ' - ', 25.810677, ' = ', 0.18932342529296875]
# [26.0, ' - ', 25.680592, ' = ', 0.3194084167480469]
# [26.0, ' - ', 25.617355, ' = ', 0.3826446533203125]
#
#
# test index: 3
# True:  [25. 24. 24. 25. 25. 24. 24. 25. 25. 25.]
# Predicted:  [25.259714 24.53574  24.609947 24.69908  25.476065 24.51207  24.733696
#  25.476192 25.074762 25.035543]
# [25.0, ' - ', 25.259714, ' = ', 0.25971412658691406]
# [24.000000000000004, ' - ', 24.53574, ' = ', 0.5357398986816371]
# [24.000000000000004, ' - ', 24.609947, ' = ', 0.6099472045898402]
# [25.0, ' - ', 24.69908, ' = ', 0.3009204864501953]
# [25.0, ' - ', 25.476065, ' = ', 0.47606468200683594]
# [24.000000000000004, ' - ', 24.51207, ' = ', 0.512069702148434]
# [24.000000000000004, ' - ', 24.733696, ' = ', 0.7336959838867152]
# [25.0, ' - ', 25.476192, ' = ', 0.4761924743652344]
# [25.0, ' - ', 25.074762, ' = ', 0.07476234436035156]
# [25.0, ' - ', 25.035543, ' = ', 0.03554344177246094]
#
#
# test index: 4
# True:  [26. 26. 26. 26. 27. 26. 26. 27. 26. 26.]
# Predicted:  [25.968891 25.787476 25.872513 25.942648 26.256245 25.678192 25.881687
#  26.678648 25.923632 25.951374]
# [26.0, ' - ', 25.968891, ' = ', 0.031108856201171875]
# [26.0, ' - ', 25.787476, ' = ', 0.2125244140625]
# [26.0, ' - ', 25.872513, ' = ', 0.1274871826171875]
# [26.0, ' - ', 25.942648, ' = ', 0.05735206604003906]
# [27.0, ' - ', 26.256245, ' = ', 0.7437553405761719]
# [26.0, ' - ', 25.678192, ' = ', 0.321807861328125]
# [26.0, ' - ', 25.881687, ' = ', 0.11831283569335938]
# [27.0, ' - ', 26.678648, ' = ', 0.3213520050048828]
# [26.0, ' - ', 25.923632, ' = ', 0.07636833190917969]
# [26.0, ' - ', 25.951374, ' = ', 0.048625946044921875]

# %% [markdown]
# # Visualizations

# %%
def plot_train_history(history, title):
  mpl.rcParams['figure.figsize'] = (8, 6)
  mpl.rcParams['axes.grid'] = False
    
  loss = history.history['loss']
  val_loss = history.history['val_loss']
    
  epochs = range(len(loss))

  y = []
  for i in epochs:
        y.append(0)

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.plot(epochs, y, 'g', label='y = 0 axis')
  plt.xlabel('Epochs')
  plt.ylabel('MSE value or Losses')
    
  plt.title(title)
  plt.legend()

  plt.show()

# %%
plot_train_history(fit,
                   'Visualization losses')

# %% [raw]
# mpl.rcParams['figure.figsize'] = (24,18)
# mpl.rcParams['axes.grid'] = False
# uni_data = test_df
# uni_data.index = list(test_df.index.values)
# uni_data.head()
# uni_data.plot(subplots=True)
