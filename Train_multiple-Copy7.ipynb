# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
import keras


import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import os

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %%
df1 = pd.read_csv("bef_data_1.csv")
df2 = pd.read_csv("bef_data_2.csv")
df3 = pd.read_csv("bef_data_3.csv")
df4 = pd.read_csv("bef_data_4.csv")
df5 = pd.read_csv("bef_data_5.csv")

#df1 = df1.set_index('time')
#df1.columns = ['Temp1', 'Temp2', 'Temp3', 'Temp4', 'Temp5', 'Temp6', 'Temp7', 'Temp8', 'Temp9', 'Temp10']
#df1

# %%
def shaper(arr, n_time = 1):
    arr = arr.values.tolist()
    shape_list = []
    for i in range(0, len(arr) - n_time, 1):
        time_list = []
        for j in range(n_time):
            time_list +=arr[i + j]
        shape_list.append(time_list)
        
    columns = []
    for i in range((-n_time)+1,1,1):
        columns += ["Temp1_" + str(i), 
                    "Temp2_" + str(i), 
                    "Temp3_" + str(i), 
                    "Temp4_" + str(i), 
                    "Temp5_" + str(i), 
                    "Temp6_" + str(i), 
                    "Temp7_" + str(i), 
                    "Temp8_" + str(i), 
                    "Temp9_" + str(i), 
                    "Temp10_" + str(i),
                    #'cond1_off_' + str(i),
                    #'c1_16h_' + str(i), 
                    #'c1_16l_' + str(i), 
                    #'c1_23h_' + str(i), 
                    #'c1_23l_' + str(i), 
                    #'c1_30h_' + str(i), 
                    #'c1_30l_' + str(i), 
                    #'cond2_off_' + str(i), 
                    #'c2_16h_' + str(i), 
                    #'c2_16l_' + str(i), 
                    #'c2_23h_' + str(i), 
                    #'c2_23l_' + str(i), 
                    #'c2_30h_' + str(i), 
                    #'c2_30l_' + str(i)
                   ]
    
    td = pd.DataFrame(shape_list, columns = columns)
    return td

def union_shaper(df_list, n_time = 1):
    frames = []
    for i in range(len(df_list)):
        df = pd.DataFrame(df_list[i], columns = ["time", "Temp1","Temp2", "Temp3", "Temp4", "Temp5", "Temp6", "Temp7", "Temp8", "Temp9", "Temp10"])
        df = df.set_index('time')
        df.columns = ['Temp1', 'Temp2', 'Temp3', 'Temp4', 'Temp5', 'Temp6', 'Temp7', 'Temp8', 'Temp9', 'Temp10']
        df = shaper(df, n_time)
        
        df['Temp1+1'] = df['Temp1_0'].shift(-1)
        df['Temp2+1'] = df['Temp2_0'].shift(-1)
        df['Temp3+1'] = df['Temp3_0'].shift(-1)
        df['Temp4+1'] = df['Temp4_0'].shift(-1)
        df['Temp5+1'] = df['Temp5_0'].shift(-1)
        df['Temp6+1'] = df['Temp6_0'].shift(-1)
        df['Temp7+1'] = df['Temp7_0'].shift(-1)
        df['Temp8+1'] = df['Temp8_0'].shift(-1)
        df['Temp9+1'] = df['Temp9_0'].shift(-1)
        df['Temp10+1'] = df['Temp10_0'].shift(-1)

        df['Temp1+1'].fillna(24, inplace=True)
        df['Temp2+1'].fillna(24, inplace=True)
        df['Temp3+1'].fillna(24, inplace=True)
        df['Temp4+1'].fillna(24, inplace=True)
        df['Temp5+1'].fillna(24, inplace=True)
        df['Temp6+1'].fillna(24, inplace=True)
        df['Temp7+1'].fillna(24, inplace=True)
        df['Temp8+1'].fillna(24, inplace=True)
        df['Temp9+1'].fillna(24, inplace=True)
        df['Temp10+1'].fillna(24, inplace=True)
        frames.append(df)
    return pd.concat(frames, ignore_index=True)

# %%
N_TIME = 12
df = union_shaper([df1, df2, df3, df4, df5], N_TIME)
df
# Out:
#      Temp1_-11  Temp2_-11  Temp3_-11  Temp4_-11  Temp5_-11  Temp6_-11  \
# 0           28         27         27         27         28         27
# 1           27         27         27         27         28         27
# 2           27         27         27         27         27         26
# 3           27         26         26         27         27         26
# 4           27         26         26         26         27         26
# ..         ...        ...        ...        ...        ...        ...
# 941         24         23         23         23         24         23
# 942         24         23         23         23         24         23
# 943         24         23         23         24         24         23
# 944         23         22         23         23         23         22
# 945         24         24         24         24         25         23
#
#      Temp7_-11  Temp8_-11  Temp9_-11  Temp10_-11  ...  Temp1+1  Temp2+1  \
# 0           27         28         27          27  ...     25.0     25.0
# 1           27         28         27          27  ...     25.0     25.0
# 2           26         27         27          27  ...     25.0     25.0
# 3           26         27         27          27  ...     25.0     25.0
# 4           26         27         27          27  ...     25.0     25.0
# ..         ...        ...        ...         ...  ...      ...      ...
# 941         23         24         23          23  ...     25.0     24.0
# 942         23         24         23          23  ...     25.0     24.0
# 943         23         24         23          23  ...     25.0     24.0
# 944         22         23         23          23  ...     25.0     24.0
# 945         24         24         24          24  ...     24.0     24.0
#
#      Temp3+1  Temp4+1  Temp5+1  Temp6+1  Temp7+1  Temp8+1  Temp9+1  Temp10+1
# 0       25.0     25.0     26.0     25.0     25.0     26.0     25.0      25.0
# 1       25.0     26.0     26.0     25.0     25.0     26.0     25.0      25.0
# 2       25.0     25.0     26.0     25.0     25.0     26.0     25.0      25.0
# 3       25.0     25.0     25.0     25.0     25.0     26.0     25.0      25.0
# 4       25.0     25.0     25.0     25.0     25.0     26.0     25.0      25.0
# ..       ...      ...      ...      ...      ...      ...      ...       ...
# 941     24.0     24.0     25.0     24.0     24.0     25.0     25.0      25.0
# 942     24.0     25.0     25.0     24.0     25.0     25.0     25.0      25.0
# 943     25.0     25.0     25.0     24.0     25.0     25.0     25.0      25.0
# 944     25.0     25.0     26.0     25.0     25.0     25.0     25.0      25.0
# 945     24.0     24.0     24.0     24.0     24.0     24.0     24.0      24.0
#
# [946 rows x 130 columns]

# %% [raw]
# df['Temp1+1'] = df['Temp1_0'].shift(-1)
# df['Temp2+1'] = df['Temp2_0'].shift(-1)
# df['Temp3+1'] = df['Temp3_0'].shift(-1)
# df['Temp4+1'] = df['Temp4_0'].shift(-1)
# df['Temp5+1'] = df['Temp5_0'].shift(-1)
# df['Temp6+1'] = df['Temp6_0'].shift(-1)
# df['Temp7+1'] = df['Temp7_0'].shift(-1)
# df['Temp8+1'] = df['Temp8_0'].shift(-1)
# df['Temp9+1'] = df['Temp9_0'].shift(-1)
# df['Temp10+1'] = df['Temp10_0'].shift(-1)
#
# df['Temp1+1'].fillna(24, inplace=True)
# df['Temp2+1'].fillna(24, inplace=True)
# df['Temp3+1'].fillna(24, inplace=True)
# df['Temp4+1'].fillna(24, inplace=True)
# df['Temp5+1'].fillna(24, inplace=True)
# df['Temp6+1'].fillna(24, inplace=True)
# df['Temp7+1'].fillna(24, inplace=True)
# df['Temp8+1'].fillna(24, inplace=True)
# df['Temp9+1'].fillna(24, inplace=True)
# df['Temp10+1'].fillna(24, inplace=True)

# %%
x = df.drop(['Temp1+1', 'Temp2+1', 'Temp3+1', 'Temp4+1', 'Temp5+1', 'Temp6+1', 'Temp7+1', 'Temp8+1', 'Temp9+1', 'Temp10+1'], axis = 1)
y = df[['Temp1+1', 'Temp2+1', 'Temp3+1', 'Temp4+1', 'Temp5+1', 'Temp6+1', 'Temp7+1', 'Temp8+1', 'Temp9+1', 'Temp10+1']]

y=np.reshape(y.values, (-1,10))

scaler_x = MinMaxScaler()
print(scaler_x.fit(x))
scaler_y = MinMaxScaler()
print(scaler_y.fit(y))
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %% [markdown]
# # Variants

# %%
X_train = scaler_x.transform(x)
y_train = scaler_y.transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.2)

# %% [raw]
# X_test = scaler_x.transform(x[87:100])
# y_test = scaler_y.transform(y[87:100])

# %% [markdown]
# xscale=scaler_x.transform(x)
# yscale=scaler_y.transform(y)
#
# X_train, X_test, y_train, y_test = train_test_split(xscale, yscale, train_size = 1)

# %% [markdown]
# # Neural Link

# %%
model = Sequential()
model.add(Dense(2048, input_dim=10 * N_TIME, kernel_initializer='normal', activation='relu'))
model.add(Dense(4096))
model.add(Dense(10, activation='softmax'))
model.summary()
# Use a custom metricfunction

model.compile(optimizer=keras.optimizers.RMSprop(), loss='mse')

fit = model.fit(X_train, y_train, epochs=100,  verbose=1, validation_split=0.1)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 2048)              247808
# _________________________________________________________________
# dense_19 (Dense)             (None, 4096)              8392704
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                40970
# =================================================================
# Total params: 8,681,482
# Trainable params: 8,681,482
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 22/22 [==============================] - 2s 106ms/step - loss: 0.2174 - val_loss: 0.2337
# Epoch 2/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.2299 - val_loss: 0.2311
# Epoch 3/100
# 22/22 [==============================] - 2s 105ms/step - loss: 0.2283 - val_loss: 0.2311
# Epoch 4/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.2287 - val_loss: 0.2337
# Epoch 5/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.2213 - val_loss: 0.2372
# Epoch 6/100
# 22/22 [==============================] - 2s 110ms/step - loss: 0.2240 - val_loss: 0.1859
# Epoch 7/100
# 22/22 [==============================] - 3s 117ms/step - loss: 0.2190 - val_loss: 0.1894
# Epoch 8/100
# 22/22 [==============================] - 2s 107ms/step - loss: 0.2298 - val_loss: 0.2102
# Epoch 9/100
# 22/22 [==============================] - 3s 114ms/step - loss: 0.2233 - val_loss: 0.2260
# Epoch 10/100
# 22/22 [==============================] - 2s 106ms/step - loss: 0.2273 - val_loss: 0.2199
# Epoch 11/100
# 22/22 [==============================] - 2s 111ms/step - loss: 0.2259 - val_loss: 0.2346
# Epoch 12/100
# 22/22 [==============================] - 2s 109ms/step - loss: 0.2239 - val_loss: 0.2333
# Epoch 13/100
# 22/22 [==============================] - 2s 106ms/step - loss: 0.2254 - val_loss: 0.2311
# Epoch 14/100
# 22/22 [==============================] - 2s 109ms/step - loss: 0.2233 - val_loss: 0.2336
# Epoch 15/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.2243 - val_loss: 0.2359
# Epoch 16/100
# 22/22 [==============================] - 2s 107ms/step - loss: 0.2270 - val_loss: 0.2287
# Epoch 17/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.2207 - val_loss: 0.2275
# Epoch 18/100
# 22/22 [==============================] - 2s 106ms/step - loss: 0.2231 - val_loss: 0.2261
# Epoch 19/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.2196 - val_loss: 0.2159
# Epoch 20/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.1673 - val_loss: 0.1492
# Epoch 21/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.1414 - val_loss: 0.1435
# Epoch 22/100
# 22/22 [==============================] - 2s 111ms/step - loss: 0.1405 - val_loss: 0.1431
# Epoch 23/100
# 22/22 [==============================] - 2s 109ms/step - loss: 0.1401 - val_loss: 0.1432
# Epoch 24/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.1398 - val_loss: 0.1428
# Epoch 25/100
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1397 - val_loss: 0.1428
# Epoch 26/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1397 - val_loss: 0.1428
# Epoch 27/100
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1397 - val_loss: 0.1429
# Epoch 28/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1397 - val_loss: 0.1430
# Epoch 29/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1397 - val_loss: 0.1428
# Epoch 30/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1397 - val_loss: 0.1427
# Epoch 31/100
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1397 - val_loss: 0.1427
# Epoch 32/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1397 - val_loss: 0.1428
# Epoch 33/100
# 22/22 [==============================] - 2s 100ms/step - loss: 0.1397 - val_loss: 0.1427
# Epoch 34/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1397 - val_loss: 0.1427
# Epoch 35/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1397 - val_loss: 0.1427
# Epoch 36/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1397 - val_loss: 0.1426
# Epoch 37/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1397 - val_loss: 0.1426
# Epoch 38/100
# 22/22 [==============================] - 2s 99ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 39/100
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1397 - val_loss: 0.1426
# Epoch 40/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 41/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 42/100
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1397 - val_loss: 0.1427
# Epoch 43/100
# 22/22 [==============================] - 2s 109ms/step - loss: 0.1396 - val_loss: 0.1428
# Epoch 44/100
# 22/22 [==============================] - 2s 112ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 45/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1397 - val_loss: 0.1426
# Epoch 46/100
# 22/22 [==============================] - 3s 115ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 47/100
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 48/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1396 - val_loss: 0.1428
# Epoch 49/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 50/100
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 51/100
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 52/100
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1396 - val_loss: 0.1428
# Epoch 53/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 54/100
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 55/100
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1396 - val_loss: 0.1431
# Epoch 56/100
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1396 - val_loss: 0.1430
# Epoch 57/100
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1396 - val_loss: 0.1429
# Epoch 58/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 59/100
# 22/22 [==============================] - 2s 113ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 60/100
# 22/22 [==============================] - 2s 100ms/step - loss: 0.1396 - val_loss: 0.1428
# Epoch 61/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 62/100
# 22/22 [==============================] - 2s 101ms/step - loss: 0.1396 - val_loss: 0.1429
# Epoch 63/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 64/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 65/100
# 22/22 [==============================] - 2s 107ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 66/100
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 67/100
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 68/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 69/100
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 70/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 71/100
# 22/22 [==============================] - 2s 100ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 72/100
# 22/22 [==============================] - 2s 100ms/step - loss: 0.1396 - val_loss: 0.1428
# Epoch 73/100
# 22/22 [==============================] - 2s 101ms/step - loss: 0.1396 - val_loss: 0.1431
# Epoch 74/100
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 75/100
# 22/22 [==============================] - 2s 101ms/step - loss: 0.1396 - val_loss: 0.1428
# Epoch 76/100
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 77/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 78/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 79/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 80/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 81/100
# 22/22 [==============================] - 3s 118ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 82/100
# 22/22 [==============================] - 2s 110ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 83/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 84/100
# 22/22 [==============================] - 2s 106ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 85/100
# 22/22 [==============================] - 3s 115ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 86/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 87/100
# 22/22 [==============================] - 2s 100ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 88/100
# 22/22 [==============================] - 2s 101ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 89/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 90/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 91/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1395 - val_loss: 0.1427
# Epoch 92/100
# 22/22 [==============================] - 2s 108ms/step - loss: 0.1396 - val_loss: 0.1426
# Epoch 93/100
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1395 - val_loss: 0.1426
# Epoch 94/100
# 22/22 [==============================] - 2s 104ms/step - loss: 0.1395 - val_loss: 0.1426
# Epoch 95/100
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1396 - val_loss: 0.1428
# Epoch 96/100
# 22/22 [==============================] - 2s 101ms/step - loss: 0.1395 - val_loss: 0.1426
# Epoch 97/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1395 - val_loss: 0.1427
# Epoch 98/100
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1396 - val_loss: 0.1427
# Epoch 99/100
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1395 - val_loss: 0.1427
# Epoch 100/100
# 22/22 [==============================] - 2s 105ms/step - loss: 0.1396 - val_loss: 0.1426

# %%
scores = model.evaluate(X_test, y_test, verbose=1)
print("Доля верных ответов на тестовых данных, в процентах:", round(scores[1] * 100, 4))
# Out:
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1465
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-4f7817da298b> in <module>
#       1 scores = model.evaluate(X_test, y_test, verbose=1)
# ----> 2 print("Доля верных ответов на тестовых данных, в процентах:", round(scores[1] * 100, 4))
#
# TypeError: 'float' object is not subscriptable

# %%
def pred_plot(x, y, p, index):
    mpl.rcParams['figure.figsize'] = (4, 3)
    mpl.rcParams['axes.grid'] = False
    
    history = np.transpose(np.reshape(x[index], (-1, 10)))
    
    length = history.shape[1]
    #np.reshape(X, (-1, 10))[-1].tolist()
    
    real = np.transpose(np.array(y[index]))
    
    pred = np.transpose(np.array(p[index]))
    
    for i in range(10):
        percent = (history[i].max() - history[i].min())
        result = (percent-abs(real[i] - pred[i]))/percent
        
        plt.plot(range(length), history[i], label='History')
        plt.plot(length, real[i], 'bo', label='Real')
        plt.plot(length, pred[i], 'rx', label='Predicted')
        plt.xlabel('Time')
        plt.ylabel('Temperature value')
        plt.legend(loc='upper left')
        plt.title('index: ' + str(index) + ', temp: ' + str(i+1) + '\npercent: ' + str(result*100))
        plt.show()

# %%
scaler_x.inverse_transform(X_test[:2])
# Out:
# array([[27., 26., 26., 26., 27., 26., 26., 27., 26., 26., 27., 26., 26.,
#         26., 27., 26., 26., 27., 26., 26., 26., 26., 26., 26., 26., 26.,
#         26., 27., 26., 26., 26., 26., 26., 26., 26., 26., 26., 27., 26.,
#         26., 26., 26., 26., 26., 26., 26., 26., 27., 26., 26., 27., 26.,
#         26., 26., 26., 26., 26., 27., 26., 26., 26., 26., 26., 26., 26.,
#         26., 26., 27., 26., 26., 26., 26., 26., 26., 26., 26., 26., 27.,
#         26., 26., 27., 26., 26., 26., 26., 26., 26., 27., 26., 26., 27.,
#         26., 26., 27., 27., 26., 26., 27., 26., 26., 27., 26., 26., 26.,
#         27., 26., 26., 27., 27., 26., 27., 26., 26., 26., 27., 26., 26.,
#         27., 26., 27.],
#        [25., 25., 25., 25., 25., 25., 25., 26., 25., 25., 25., 25., 25.,
#         25., 25., 25., 25., 26., 25., 25., 25., 25., 25., 25., 25., 25.,
#         25., 26., 25., 25., 25., 25., 25., 25., 25., 25., 25., 26., 25.,
#         25., 25., 25., 25., 25., 25., 25., 25., 26., 25., 25., 25., 25.,
#         25., 25., 25., 25., 25., 26., 25., 25., 25., 25., 25., 25., 25.,
#         25., 24., 26., 25., 25., 25., 25., 25., 25., 26., 25., 25., 26.,
#         25., 25., 26., 25., 25., 25., 26., 25., 25., 26., 26., 26., 26.,
#         26., 26., 26., 27., 26., 26., 27., 26., 26., 26., 26., 26., 26.,
#         27., 26., 26., 27., 26., 27., 27., 26., 26., 27., 27., 26., 26.,
#         27., 27., 27.]])

# %%
for i in range(2):
    pred_plot(scaler_x.inverse_transform(X_test[:i+1]),
              scaler_y.inverse_transform(y_test[:i+1]),
              scaler_y.inverse_transform(model.predict(X_test[:i+1])),
              i)
# Out:
# c:\users\zhastay\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()
# c:\users\zhastay\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()
# c:\users\zhastay\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()
# c:\users\zhastay\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()
# c:\users\zhastay\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in double_scalars
#   app.launch_new_instance()

# %% [markdown]
# # Testing and Experiments

# %%
for i in range(5):
    print('test index:', i)
    true = scaler_x.inverse_transform(X_test[i:i+1])[0][(N_TIME - 1) * 10:(N_TIME - 1) * 10 + 10]
    print('True: ', true)

    ynew= model.predict(X_test)
    predict = scaler_y.inverse_transform(ynew[i:i+1])[0]
    print('Predicted: ', predict)

    result = []
    for j in range(len(true)):
        result.append([true[j], " - ", predict[j], " = ", abs(true[j] - predict[j])])
    
    for j in result:
        print(j)
    print("\n")
# Out:
# test index: 0
# True:  [27. 26. 26. 26. 27. 26. 26. 27. 26. 27.]
# Predicted:  [22.224426 21.91393  22.129898 22.804796 22.7705   21.984728 21.98602
#  22.953102 22.249987 22.22995 ]
# [27.0, ' - ', 22.224426, ' = ', 4.77557373046875]
# [26.0, ' - ', 21.91393, ' = ', 4.086069107055664]
# [26.0, ' - ', 22.129898, ' = ', 3.8701019287109375]
# [26.0, ' - ', 22.804796, ' = ', 3.1952037811279297]
# [27.0, ' - ', 22.7705, ' = ', 4.229499816894531]
# [26.0, ' - ', 21.984728, ' = ', 4.01527214050293]
# [26.0, ' - ', 21.98602, ' = ', 4.013980865478516]
# [27.0, ' - ', 22.953102, ' = ', 4.046897888183594]
# [26.0, ' - ', 22.249987, ' = ', 3.7500133514404297]
# [27.0, ' - ', 22.22995, ' = ', 4.770050048828125]
#
#
# test index: 1
# True:  [27. 26. 26. 27. 27. 26. 26. 27. 27. 27.]
# Predicted:  [22.169964 21.903122 22.097683 22.866846 22.793608 22.043682 21.98991
#  22.926098 22.222837 22.218208]
# [27.0, ' - ', 22.169964, ' = ', 4.830036163330078]
# [26.0, ' - ', 21.903122, ' = ', 4.0968780517578125]
# [26.0, ' - ', 22.097683, ' = ', 3.9023170471191406]
# [27.0, ' - ', 22.866846, ' = ', 4.133153915405273]
# [27.0, ' - ', 22.793608, ' = ', 4.206392288208008]
# [26.0, ' - ', 22.043682, ' = ', 3.956317901611328]
# [26.0, ' - ', 21.98991, ' = ', 4.010089874267578]
# [27.0, ' - ', 22.926098, ' = ', 4.073902130126953]
# [27.0, ' - ', 22.222837, ' = ', 4.777162551879883]
# [27.0, ' - ', 22.218208, ' = ', 4.781791687011719]
#
#
# test index: 2
# True:  [25. 24. 24. 24. 25. 24. 24. 25. 25. 25.]
# Predicted:  [22.464127 21.824446 22.020786 22.659477 22.717    21.843498 21.838573
#  22.954365 22.526558 22.484749]
# [25.0, ' - ', 22.464127, ' = ', 2.5358734130859375]
# [24.000000000000004, ' - ', 21.824446, ' = ', 2.175554275512699]
# [24.000000000000004, ' - ', 22.020786, ' = ', 1.979213714599613]
# [24.0, ' - ', 22.659477, ' = ', 1.3405227661132812]
# [25.0, ' - ', 22.717, ' = ', 2.283000946044922]
# [24.000000000000004, ' - ', 21.843498, ' = ', 2.156501770019535]
# [24.000000000000004, ' - ', 21.838573, ' = ', 2.1614265441894567]
# [25.0, ' - ', 22.954365, ' = ', 2.045635223388672]
# [25.0, ' - ', 22.526558, ' = ', 2.4734420776367188]
# [25.0, ' - ', 22.484749, ' = ', 2.5152511596679688]
#
#
# test index: 3
# True:  [25. 25. 25. 26. 26. 25. 25. 26. 25. 25.]
# Predicted:  [22.244047 21.909164 22.056492 22.768929 22.784962 21.9504   21.97174
#  22.949087 22.326202 22.30592 ]
# [25.0, ' - ', 22.244047, ' = ', 2.755952835083008]
# [25.0, ' - ', 21.909164, ' = ', 3.0908355712890625]
# [25.0, ' - ', 22.056492, ' = ', 2.9435081481933594]
# [26.0, ' - ', 22.768929, ' = ', 3.2310714721679688]
# [26.0, ' - ', 22.784962, ' = ', 3.215038299560547]
# [25.0, ' - ', 21.9504, ' = ', 3.049600601196289]
# [25.0, ' - ', 21.97174, ' = ', 3.02825927734375]
# [26.0, ' - ', 22.949087, ' = ', 3.050912857055664]
# [25.0, ' - ', 22.326202, ' = ', 2.673797607421875]
# [25.0, ' - ', 22.30592, ' = ', 2.694080352783203]
#
#
# test index: 4
# True:  [27. 27. 27. 27. 28. 27. 27. 28. 28. 28.]
# Predicted:  [22.151133 21.921562 22.138088 22.845196 22.786304 21.952934 22.029415
#  22.95155  22.22618  22.23183 ]
# [27.0, ' - ', 22.151133, ' = ', 4.848867416381836]
# [27.0, ' - ', 21.921562, ' = ', 5.078437805175781]
# [27.0, ' - ', 22.138088, ' = ', 4.861911773681641]
# [27.0, ' - ', 22.845196, ' = ', 4.154804229736328]
# [28.0, ' - ', 22.786304, ' = ', 5.213695526123047]
# [27.0, ' - ', 21.952934, ' = ', 5.047065734863281]
# [27.0, ' - ', 22.029415, ' = ', 4.970584869384766]
# [28.0, ' - ', 22.95155, ' = ', 5.048450469970703]
# [28.0, ' - ', 22.22618, ' = ', 5.773820877075195]
# [28.0, ' - ', 22.23183, ' = ', 5.768169403076172]

# %% [markdown]
# # Visualizations

# %%
def plot_train_history(history, title):
  mpl.rcParams['figure.figsize'] = (8, 6)
  mpl.rcParams['axes.grid'] = False
    
  loss = history.history['loss']
  val_loss = history.history['val_loss']
    
  epochs = range(len(loss))

  y = []
  for i in epochs:
        y.append(0)

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.plot(epochs, y, 'g', label='y = 0 axis')
  plt.xlabel('Epochs')
  plt.ylabel('MSE value or Losses')
    
  plt.title(title)
  plt.legend()

  plt.show()

# %%
plot_train_history(fit,
                   'Visualization losses')

# %% [raw]
# mpl.rcParams['figure.figsize'] = (24,18)
# mpl.rcParams['axes.grid'] = False
# uni_data = test_df
# uni_data.index = list(test_df.index.values)
# uni_data.head()
# uni_data.plot(subplots=True)
